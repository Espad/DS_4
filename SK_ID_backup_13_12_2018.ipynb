# %%
# !pip install category_encoders
# !pip install xgboost
# Out:
# Requirement already satisfied: category_encoders in e:\python\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: scipy>=0.17.0 in e:\python\anaconda3\lib\site-packages (from category_encoders) (1.1.0)
# Requirement already satisfied: numpy>=1.11.1 in e:\python\anaconda3\lib\site-packages (from category_encoders) (1.15.4)
# Requirement already satisfied: scikit-learn>=0.17.1 in e:\python\anaconda3\lib\site-packages (from category_encoders) (0.20.0)
# Requirement already satisfied: statsmodels>=0.6.1 in e:\python\anaconda3\lib\site-packages (from category_encoders) (0.9.0)
# Requirement already satisfied: pandas>=0.20.1 in e:\python\anaconda3\lib\site-packages (from category_encoders) (0.23.4)
# Requirement already satisfied: patsy>=0.4.1 in e:\python\anaconda3\lib\site-packages (from category_encoders) (0.5.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in e:\python\anaconda3\lib\site-packages (from pandas>=0.20.1->category_encoders) (2.7.3)
# Requirement already satisfied: pytz>=2011k in e:\python\anaconda3\lib\site-packages (from pandas>=0.20.1->category_encoders) (2018.5)
# Requirement already satisfied: six in e:\python\anaconda3\lib\site-packages (from patsy>=0.4.1->category_encoders) (1.11.0)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: xgboost in e:\python\anaconda3\lib\site-packages (0.81)
# Requirement already satisfied: numpy in e:\python\anaconda3\lib\site-packages (from xgboost) (1.15.4)
# Requirement already satisfied: scipy in e:\python\anaconda3\lib\site-packages (from xgboost) (1.1.0)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# imports

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
from matplotlib import pyplot as plt
import seaborn as sns
sns.set(font_scale=1.3)
from scipy import interp

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, Imputer,OrdinalEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.preprocessing import PowerTransformer,QuantileTransformer
from sklearn.preprocessing import label_binarize
from sklearn.pipeline import make_pipeline,Pipeline,FeatureUnion
import category_encoders
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

from sklearn.metrics import roc_curve, auc

from itertools import cycle

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split, KFold,RandomizedSearchCV, cross_val_score

from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score, make_scorer, roc_auc_score
from sklearn.metrics import classification_report

from sklearn.decomposition import PCA, TruncatedSVD

import glob

from xgboost import XGBClassifier

from sklearn.feature_selection import SelectKBest, f_classif,SelectPercentile

# %matplotlib inline

# %%
source_dir = "dataset"
suffix_train = "/train/"
suffix_test =  "/test/"

filname_subs_features_train = "subs_features_train.csv"
filname_subs_bs_cons_train = "subs_bs_consumption_train.csv"
filname_subs_bs_data_session_train = "subs_bs_data_session_train.csv"
filname_subs_bs_voice_session_train = "subs_bs_voice_session_train.csv"


filname_subs_features_test= "subs_features_test.csv"
filname_subs_bs_cons_test = "subs_bs_consumption_test.csv"
filname_subs_bs_data_session_test = "subs_bs_data_session_test.csv"
filname_subs_bs_voice_session_test = "subs_bs_voice_session_test.csv"

filname_y_train = "subs_csi_train.csv"
filname_y_test = "subs_csi_test.csv"

filename_bs_avg_kpi = "bs_avg_kpi.csv"

target = "CSI"
seed = 33

# %% [markdown]
# Считаем train/test файлы.

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%d.%m.%y')



#features
df_sfeatures_train = pd.read_csv(source_dir + suffix_train + filname_subs_features_train, 
                             header=0, sep = ';', decimal=",")

df_sfeatures_test = pd.read_csv(source_dir + suffix_test + filname_subs_features_test, 
                             header=0, sep = ';', decimal=",")

#bs consumption
df_bsconsumption_train = pd.read_csv(source_dir + suffix_train + filname_subs_bs_cons_train, 
                             header=0, sep = ';', decimal=",")

df_bsconsumption_test = pd.read_csv(source_dir + suffix_test + filname_subs_bs_cons_test, 
                             header=0, sep = ';', decimal=",")

#data session
df_datasession_train = pd.read_csv(source_dir + suffix_train + filname_subs_bs_data_session_train, 
                             header=0, sep = ';', decimal=",")

df_datasession_test = pd.read_csv(source_dir + suffix_test + filname_subs_bs_data_session_test, 
                             header=0, sep = ';', decimal=",")


#voice session
df_voicesession_train = pd.read_csv(source_dir + suffix_train + filname_subs_bs_voice_session_train, 
                             header=0, sep = ';', decimal=",")

df_voicesession_test = pd.read_csv(source_dir + suffix_test + filname_subs_bs_voice_session_test, 
                             header=0, sep = ';', decimal=",")



# results
df_y_train = pd.read_csv(source_dir + suffix_train + filname_y_train, 
                             header=0, sep = ';', decimal=",")

df_y_test_pred = pd.read_csv(source_dir + suffix_test + filname_y_test, 
                             header=0, sep = ';', decimal=",")

# %%
df_bs_avg_kpi = pd.read_csv(source_dir + '/' +filename_bs_avg_kpi, 
                             header=0, sep = ';', decimal=",", nrows=10000)

# %%time
ffpath = "dataset/preprocessed/"
chunk_size = 500000
appended_data = []
i = 0
for gm_chunk in pd.read_csv(source_dir + '/' +filename_bs_avg_kpi,header=0, 
                            sep = ';', decimal=",", chunksize = chunk_size):
    i+=1
    gm_chunk[['T_DATE']] = gm_chunk['T_DATE'].str.split('.',expand=True)[1] # getting only months
    gm_chunk.rename(columns={'T_DATE':'T_DATE_month'}, inplace=True)
    gm_chunk.groupby(['T_DATE_month','CELL_LAC_ID'],sort=False,as_index = False).mean()
    gm_chunk = pd.DataFrame(gm_chunk)
    gm_chunk.to_csv(ffpath + i + ".csv", sep='\t', encoding='utf-8',index = False, header = False)
    #appended_data.append(gm_chunk)

del appended_data

backup = appended_data.copy()

appended_data = pd.DataFrame(appended_data)

appended_data

# %%
test_chunk = gm_chunk.copy()

test_chunk.head()
#test_chunk.CELL_LAC_ID.value_counts()

test_chunk[['T_DATE']] = test_chunk['T_DATE'].str.split('.',expand=True)[1] # getting only months

test_chunk.rename(columns={'T_DATE':'T_DATE_month'}, inplace=True)

test_chunk =  test_chunk.groupby(['T_DATE_month','CELL_LAC_ID'],sort=False,as_index = False).mean()
test_chunk = test_chunk[test_chunk.CELL_LAC_ID == 378360]

test_chunk

#print (pd.concat([1- test_chunk.count() / test_chunk.shape[0], test_chunk.isna().sum()],axis=1))

# %% [markdown]
# #### Test voice/data sessions.

# %%
# сливаем два массива в 1
df_datasession = pd.concat([df_datasession_train,df_datasession_test], axis=0, sort = False)
df_voicesession = pd.concat([df_voicesession_train,df_voicesession_test], axis=0, sort = False)

# %%
del df_datasession_train
del df_datasession_test
del df_voicesession_train
del df_voicesession_test

# %%
for_test_data = df_datasession[df_datasession['SK_ID'] == 1827]
for_test_voice = df_voicesession[df_voicesession['SK_ID'] == 1827]


for_test_data = for_test_data.groupby(['SK_ID','CELL_LAC_ID'],sort=False,as_index = False).agg({
    'DATA_VOL_MB' : ['sum','count'],# total minutes by all cells
    #'DATA_VOL_MB' : ['count']# total minutes by all cells
})

for_test_voice = for_test_voice.groupby(['SK_ID','CELL_LAC_ID'],sort=False,as_index = False).agg({
    'VOICE_DUR_MIN' : ['sum','count'],# total minutes by all cells
    #'DATA_VOL_MB' : ['count']# total minutes by all cells
})

# %%
for_test_data.columns = for_test_data.columns.droplevel(1)
for_test_data.columns = ['SK_ID', 'CELL_LAC_ID', 'DATA_VOL_MB_BY_CELL', 'FREQ_BY_CELL']

for_test_voice.columns = for_test_voice.columns.droplevel(1)
for_test_voice.columns = ['SK_ID', 'CELL_LAC_ID', 'VOICE_DUR_MIN_BY_CELL', 'FREQ_BY_CELL']

# %%
for_test_data = for_test_data.sort_values(by = 'FREQ_BY_CELL',axis=0, ascending=False)
for_test_voice = for_test_voice.sort_values(by = 'FREQ_BY_CELL',axis=0, ascending=False)

# %%
for_test = pd.merge(for_test_data, for_test_voice,  on=['CELL_LAC_ID'],how = 'left')

for_test.drop(['SK_ID_y'],axis = 1, inplace = True)

# %%
for_test.sort_values(by = ['FREQ_BY_CELL_x','FREQ_BY_CELL_y'],axis=0, ascending=False)
# Out:
#      SK_ID_x  CELL_LAC_ID  DATA_VOL_MB_BY_CELL  FREQ_BY_CELL_x  \
# 0       1827       347501         1.546340e-01              69
# 1       1827        91111         2.828037e-02              21
# 2       1827       350978         3.134294e-02              20
# 3       1827       315010         1.844417e-02              15
# 4       1827        49336         2.226874e-02              14
# 5       1827       362863         1.458268e-02              13
# 6       1827       271241         2.236066e-02              13
# 7       1827       357179         6.607070e-04               9
# 8       1827       125250         3.555298e-04               5
# 9       1827        77514         9.785827e-03               5
# 10      1827       289500         9.092074e-04               5
# 12      1827        23405         1.406000e-02               4
# 13      1827        34411         9.939144e-03               4
# 11      1827       162616         1.869238e-03               4
# 14      1827       181546         3.032067e-04               4
# 15      1827        30515         4.611893e-06               3
# 21      1827        54450         4.942692e-03               3
# 18      1827        24690         2.769968e-03               3
# 23      1827       161049         1.209954e-03               3
# 16      1827       281136         2.235471e-03               3
# 17      1827        71711         1.521571e-05               3
# 19      1827       211311         6.688185e-03               3
# 20      1827       272109         1.587934e-04               3
# 22      1827        31376         3.087059e-03               3
# 24      1827       215676         2.599731e-06               3
# 36      1827       322390         1.147673e-03               2
# 37      1827       176454         5.279792e-03               2
# 26      1827       185031         9.336891e-04               2
# 39      1827       234936         9.695327e-04               2
# 40      1827        38648         2.006049e-03               2
# ..       ...          ...                  ...             ...
# 72      1827       349356         6.698464e-03               1
# 77      1827        51169         1.441760e-05               1
# 80      1827        92698         3.914070e-05               1
# 81      1827         5688         3.874362e-08               1
# 83      1827         8034         6.552727e-06               1
# 85      1827        47686         6.890769e-04               1
# 87      1827       244268         3.063631e-04               1
# 88      1827         6011         3.081363e-04               1
# 89      1827       189788         6.103674e-04               1
# 91      1827       270264         1.654212e-03               1
# 92      1827       182652         1.713921e-05               1
# 93      1827       175458         6.613901e-06               1
# 97      1827       140814         2.477877e-03               1
# 98      1827       234847         1.614020e-06               1
# 100     1827       205346         1.403069e-03               1
# 101     1827       127869         2.284433e-05               1
# 103     1827       134225         3.165226e-05               1
# 104     1827       140124         1.793735e-04               1
# 105     1827       190523         8.924924e-06               1
# 107     1827       194151         3.075238e-04               1
# 108     1827       332772         1.019879e-03               1
# 110     1827       183800         9.941550e-04               1
# 111     1827       245282         2.825820e-06               1
# 115     1827       332411         6.694787e-06               1
# 116     1827       120696         1.177534e-05               1
# 118     1827       208085         1.268991e-04               1
# 119     1827       212403         1.094453e-04               1
# 120     1827         9776         5.216370e-07               1
# 122     1827       194153         3.919690e-06               1
# 125     1827       246387         1.911275e-05               1
#
#      VOICE_DUR_MIN_BY_CELL  FREQ_BY_CELL_y
# 0                      NaN             NaN
# 1                 0.143750            23.0
# 2                 0.775625           111.0
# 3                 0.522778            58.0
# 4                 0.259583            27.0
# 5                 0.484792            54.0
# 6                 0.141667            25.0
# 7                      NaN             NaN
# 8                      NaN             NaN
# 9                      NaN             NaN
# 10                     NaN             NaN
# 12                0.088333            11.0
# 13                0.083333            10.0
# 11                     NaN             NaN
# 14                     NaN             NaN
# 15                0.035486            21.0
# 21                0.060139             7.0
# 18                0.006181             2.0
# 23                0.003125             2.0
# 16                0.000556             1.0
# 17                     NaN             NaN
# 19                     NaN             NaN
# 20                     NaN             NaN
# 22                     NaN             NaN
# 24                     NaN             NaN
# 36                0.052500            11.0
# 37                0.048542             9.0
# 26                0.093264             6.0
# 39                0.057361             6.0
# 40                0.034931             5.0
# ..                     ...             ...
# 72                     NaN             NaN
# 77                     NaN             NaN
# 80                     NaN             NaN
# 81                     NaN             NaN
# 83                     NaN             NaN
# 85                     NaN             NaN
# 87                     NaN             NaN
# 88                     NaN             NaN
# 89                     NaN             NaN
# 91                     NaN             NaN
# 92                     NaN             NaN
# 93                     NaN             NaN
# 97                     NaN             NaN
# 98                     NaN             NaN
# 100                    NaN             NaN
# 101                    NaN             NaN
# 103                    NaN             NaN
# 104                    NaN             NaN
# 105                    NaN             NaN
# 107                    NaN             NaN
# 108                    NaN             NaN
# 110                    NaN             NaN
# 111                    NaN             NaN
# 115                    NaN             NaN
# 116                    NaN             NaN
# 118                    NaN             NaN
# 119                    NaN             NaN
# 120                    NaN             NaN
# 122                    NaN             NaN
# 125                    NaN             NaN
#
# [126 rows x 6 columns]

# %%
for_test_consumption = df_bsconsumption[df_bsconsumption['SK_ID'] == 1827]

for_test_consumption = for_test_consumption.groupby('CELL_LAC_ID',sort=False,as_index = False).agg({
    'SK_ID' : 'first',
    'SUM_MINUTES' : ['sum'],# total minutes by all cells
    'SUM_DATA_MB' : ['sum'],#  total data by all cells
    'SUM_DATA_MIN' : ['sum']# total cells length
})

for_test_consumption.columns = for_test_consumption.columns.droplevel(1)
for_test_consumption
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1669-4f3720f3bc52> in <module>()
#       1 for_test_consumption = df_bsconsumption[df_bsconsumption['SK_ID'] == 1827]
#       2
# ----> 3 for_test_consumption = for_test_consumption.groupby('CELL_LAC_ID',sort=False,as_index = False).agg({
#       4     'SK_ID' : 'first',
#       5     'SUM_MINUTES' : ['sum'],# total minutes by all cells
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'CELL_LAC_ID'

# %%
#False for ranks by high (1) to low (N)
for_test['rank'] = for_test['SUM_MINUTES'].rank(ascending=True,method = 'dense')
for_test['rank2'] = for_test['SUM_DATA_MB'].rank(ascending=True,method = 'dense')
for_test['rank3'] = for_test['SUM_DATA_MIN'].rank(ascending=True,method = 'dense')
for_test['result_rank'] = for_test['rank'].values + for_test['rank2'].values + for_test['rank3'].values
for_test.drop(['rank','rank2','rank3'],axis = 1, inplace = True)
for_test[for_test.result_rank > 300].sort_values('result_rank')

'''#df_bsconsumption_train['CELL_MAX_MINUTES_ID'] 
#cell with max minutes
max_ind = for_test.SUM_MINUTES.idxmax()
print (
for_test[for_test.index == max_ind][['CELL_LAC_ID','MON','SUM_MINUTES']]
)


#cell with max data
max_ind = for_test.SUM_DATA_MB.idxmax()
print (
for_test[for_test.index == max_ind][['CELL_LAC_ID','MON','SUM_DATA_MB']]
)

#cell with length session
max_ind = for_test.SUM_DATA_MIN.idxmax()
print (
for_test[for_test.index == max_ind][['CELL_LAC_ID','MON','SUM_DATA_MIN']]
)



#cell with min minutes
max_ind = for_test.SUM_MINUTES.idxmin()
print (
for_test[for_test.index == max_ind][['CELL_LAC_ID','MON','SUM_MINUTES']]
)


#cell with min data
max_ind = for_test.SUM_DATA_MB.idxmin()
print (
for_test[for_test.index == max_ind][['CELL_LAC_ID','MON','SUM_DATA_MB']]
)

#cell with length session
max_ind = for_test.SUM_DATA_MIN.idxmin()
print (
for_test[for_test.index == max_ind][['CELL_LAC_ID','MON','SUM_DATA_MIN']]
)'''
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1574-e54032a35c77> in <module>()
#       1 for_test = df_bsconsumption[df_bsconsumption['SK_ID'] == 1827]
#       2
# ----> 3 for_test = for_test.groupby('CELL_LAC_ID',sort=False,as_index = False).agg({
#       4     'SK_ID' : 'first',
#       5     'SUM_MINUTES' : ['sum'],# total minutes by all cells
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'CELL_LAC_ID'

# %%
# сливаем два массива в 1
df_bsconsumption = pd.concat([df_bsconsumption_train,df_bsconsumption_test], axis=0, sort = False)

# %%
del df_bsconsumption_train
del df_bsconsumption_test

# %%
# производим аггрегацию
df_bsconsumption = df_bsconsumption.groupby('SK_ID',sort=False,as_index = False).agg({
    #'CELL_LAC_ID' : 'count', # get count of cells by sk_id
    'SUM_MINUTES' : ['sum'],# total minutes by all cells
    'SUM_DATA_MB' : ['sum'],#  total data by all cells
    'SUM_DATA_MIN' : ['sum']# total cells length
    # max cell with minutes, data, data_min
    #'CELL_LAC_ID' : ['']
   
})
df_bsconsumption.columns = df_bsconsumption.columns.droplevel(1)

# %%
df_union_train = pd.merge(df_y_train, df_sfeatures_train, on=['SK_ID'])

# %%
df_union_test = pd.merge(df_y_test_pred,df_sfeatures_test, on=['SK_ID'])

# %%
df = pd.concat([df_union_train,df_union_test], axis=0, sort = False)

# %%
del df_union_train

# %%
del df_union_test

# %%
df.shape
# Out:
# (106400, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106400 entries, 0 to 58988
# Data columns (total 38 columns):
# SK_ID               106400 non-null int64
# CSI                 47411 non-null float64
# CONTACT_DATE        106400 non-null object
# SNAP_DATE           106400 non-null object
# COM_CAT#1           106400 non-null int64
# COM_CAT#2           106400 non-null int64
# COM_CAT#3           106400 non-null int64
# BASE_TYPE           106400 non-null int64
# ACT                 106400 non-null int64
# ARPU_GROUP          106358 non-null float64
# COM_CAT#7           106400 non-null int64
# COM_CAT#8           101541 non-null float64
# DEVICE_TYPE_ID      106098 non-null float64
# INTERNET_TYPE_ID    106098 non-null float64
# REVENUE             106400 non-null float64
# ITC                 106400 non-null float64
# VAS                 106400 non-null float64
# RENT_CHANNEL        106400 non-null float64
# ROAM                106400 non-null float64
# COST                106400 non-null float64
# COM_CAT#17          106400 non-null float64
# COM_CAT#18          106400 non-null float64
# COM_CAT#19          106400 non-null float64
# COM_CAT#20          106400 non-null float64
# COM_CAT#21          106400 non-null float64
# COM_CAT#22          106400 non-null float64
# COM_CAT#23          106400 non-null float64
# COM_CAT#24          106400 non-null object
# COM_CAT#25          106400 non-null int64
# COM_CAT#26          106400 non-null int64
# COM_CAT#27          106400 non-null float64
# COM_CAT#28          106400 non-null float64
# COM_CAT#29          106400 non-null float64
# COM_CAT#30          106400 non-null float64
# COM_CAT#31          106400 non-null float64
# COM_CAT#32          106400 non-null float64
# COM_CAT#33          106400 non-null float64
# COM_CAT#34          102936 non-null float64
# dtypes: float64(26), int64(9), object(3)
# memory usage: 31.7+ MB

# %%
# set option to view more columns as by default
pd.set_option('display.max_columns', df.shape[1])

# %%
df.columns = df.columns.str.replace("[#]", "_")

# %%
df.head()
# Out:
#    SK_ID  CSI CONTACT_DATE SNAP_DATE  COM_CAT_1  COM_CAT_2  COM_CAT_3  \
# 0      2  0.0        04.05  01.03.02          7         77         10
# 1      2  0.0        04.05  01.02.02          7         77          9
# 2      2  0.0        04.05  01.05.02          7         77         12
# 3      2  0.0        04.05  01.01.02          7         77         17
# 4      2  0.0        04.05  01.04.02          7         77         11
#
#    BASE_TYPE  ACT  ARPU_GROUP  COM_CAT_7  COM_CAT_8  DEVICE_TYPE_ID  \
# 0          1    1        10.0          2     1318.0             5.0
# 1          1    1        10.0          2     1318.0             5.0
# 2          1    1         9.0          2     1318.0             5.0
# 3          1    1         6.0          2     1318.0             5.0
# 4          1    1         8.0          2     1318.0             5.0
#
#    INTERNET_TYPE_ID   REVENUE       ITC       VAS  RENT_CHANNEL  ROAM  \
# 0               2.0  0.133708  0.007335  0.084167      0.055325   0.0
# 1               2.0  0.134224  0.001590  0.084167      0.055312   0.0
# 2               2.0  0.128917  0.008331  0.084167      0.055257   0.0
# 3               2.0  0.117077  0.002301  0.084167      0.055353   0.0
# 4               2.0  0.126715  0.002080  0.084167      0.055187   0.0
#
#        COST  COM_CAT_17  COM_CAT_18  COM_CAT_19  COM_CAT_20  COM_CAT_21  \
# 0  0.004982         0.0         0.0    0.026212    0.706893    0.019298
# 1  0.004396         0.0         0.0    0.026212    0.707528    0.019298
# 2  0.005078         0.0         0.0    0.026212    0.705129    0.019298
# 3  0.004471         0.0         0.0    0.087185    0.701424    0.086379
# 4  0.004436         0.0         0.0    0.026212    0.704850    0.019298
#
#    COM_CAT_22  COM_CAT_23 COM_CAT_24  COM_CAT_25  COM_CAT_26  COM_CAT_27  \
# 0    0.706893    0.133897      31.12           1           1    0.002070
# 1    0.707528    0.134836      31.12           1           1    0.003913
# 2    0.705129    0.129093      31.12           1           1    0.001801
# 3    0.697846    0.118129      31.12           1           0    0.001798
# 4    0.704850    0.126587      31.12           1           1    0.006520
#
#    COM_CAT_28  COM_CAT_29  COM_CAT_30  COM_CAT_31  COM_CAT_32  COM_CAT_33  \
# 0    0.007335    0.000050    0.002785    0.029765    0.027579    0.103896
# 1    0.001590    0.000018    0.001954    0.054871    0.027579    0.103896
# 2    0.008317    0.000081    0.002441    0.018126    0.027579    0.103896
# 3    0.002048    0.000033    0.002331    0.022108    0.027579    0.103896
# 4    0.001408    0.000010    0.001709    0.022772    0.027579    0.103896
#
#    COM_CAT_34
# 0         NaN
# 1         NaN
# 2         9.0
# 3         NaN
# 4         9.0

# %%
df.tail()
# Out:
#        SK_ID  CSI CONTACT_DATE SNAP_DATE  COM_CAT_1  COM_CAT_2  COM_CAT_3  \
# 58984   6156  NaN        14.04  01.03.02          4         54          5
# 58985   6156  NaN        14.04  01.08.01          4         54          5
# 58986   6156  NaN        14.04  01.05.01          4         54          5
# 58987   6156  NaN        14.04  01.04.02          4         54          5
# 58988   6156  NaN        14.04  01.10.01          4         54          5
#
#        BASE_TYPE  ACT  ARPU_GROUP  COM_CAT_7  COM_CAT_8  DEVICE_TYPE_ID  \
# 58984          2    1         4.0          3     1324.0             5.0
# 58985          2    1         1.0          3     1324.0             5.0
# 58986          2    1         2.0          3     1324.0             5.0
# 58987          2    1         1.0          3     1324.0             5.0
# 58988          2    1         4.0          3     1324.0             5.0
#
#        INTERNET_TYPE_ID   REVENUE       ITC       VAS  RENT_CHANNEL  ROAM  \
# 58984               2.0  0.110392  0.000728  0.084167      0.054969   0.0
# 58985               2.0  0.108153  0.000000  0.084167      0.054966   0.0
# 58986               2.0  0.108803  0.002199  0.084418      0.055716   0.0
# 58987               2.0  0.108261  0.000000  0.084167      0.054968   0.0
# 58988               2.0  0.110345  0.000177  0.084167      0.054971   0.0
#
#            COST  COM_CAT_17  COM_CAT_18  COM_CAT_19  COM_CAT_20  COM_CAT_21  \
# 58984  0.004281         0.0         0.0    0.026212    0.699214    0.019298
# 58985  0.004206         0.0         0.0    0.026212    0.698482    0.019298
# 58986  0.004506         0.0         0.0    0.026212    0.698480    0.019298
# 58987  0.004207         0.0         0.0    0.026212    0.698520    0.019298
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.004429       0.000000       0.000000
# 50%         0.000000       0.005209       0.000000       0.000000
# 75%         0.000000       0.007087       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#           COM_CAT_19     COM_CAT_20     COM_CAT_21     COM_CAT_22  \
# count  106400.000000  106400.000000  106400.000000  106400.000000
# mean        0.026593       0.704000       0.019748       0.703853
# std         0.010831       0.006346       0.004545       0.006369
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.026212       0.700358       0.019298       0.700214
# 50%         0.026212       0.702849       0.019298       0.702705
# 75%         0.026212       0.705948       0.019298       0.705816
# max         1.000000       1.000000       1.000000       1.000000
#
#           COM_CAT_23     COM_CAT_25     COM_CAT_26     COM_CAT_27  \
# count  106400.000000  106400.000000  106400.000000  106400.000000
# mean        0.126349       0.999878       0.988769       0.016675
# std         0.018020       0.011053       0.105381       0.024760
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.115037       1.000000       1.000000       0.002037
# 50%         0.122497       1.000000       1.000000       0.008221
# 75%         0.131878       1.000000       1.000000       0.021532
# max         1.000000       1.000000       1.000000       1.000000
#
#           COM_CAT_28     COM_CAT_29     COM_CAT_30     COM_CAT_31  \
# count  106400.000000  106400.000000  106400.000000  106400.000000
# mean        0.017986       0.004444       0.004695       0.045831
# std         0.030927       0.015495       0.021385       0.051868
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000960       0.000000       0.000000       0.010774
# 50%         0.006679       0.000070       0.000000       0.030382
# 75%         0.022035       0.002882       0.000190       0.062889
# max         1.000000       1.000000       1.000000       1.000000
#
#           COM_CAT_32     COM_CAT_33     COM_CAT_34
# count  106400.000000  106400.000000  102936.000000
# mean        0.028238       0.104961       5.582323
# std         0.009022       0.009838       3.557936
# min         0.000000       0.000000       1.000000
# 25%         0.027579       0.103896       2.000000
# 50%         0.027579       0.103896       4.000000
# 75%         0.027579       0.103896       9.000000
# max         1.000000       1.000000      10.000000

# %% [markdown]
# Missing values

# %%
print (pd.concat([1- df.count() / df.shape[0], df.isna().sum()],axis=1))
# Out:
#                          0      1
# SK_ID             0.000000      0
# CSI               0.554408  58989
# CONTACT_DATE      0.000000      0
# SNAP_DATE         0.000000      0
# COM_CAT_1         0.000000      0
# COM_CAT_2         0.000000      0
# COM_CAT_3         0.000000      0
# BASE_TYPE         0.000000      0
# ACT               0.000000      0
# ARPU_GROUP        0.000395     42
# COM_CAT_7         0.000000      0
# COM_CAT_8         0.045667   4859
# DEVICE_TYPE_ID    0.002838    302
# INTERNET_TYPE_ID  0.002838    302
# REVENUE           0.000000      0
# ITC               0.000000      0
# VAS               0.000000      0
# RENT_CHANNEL      0.000000      0
# ROAM              0.000000      0
# COST              0.000000      0
# COM_CAT_17        0.000000      0
# COM_CAT_18        0.000000      0
# COM_CAT_19        0.000000      0
# COM_CAT_20        0.000000      0
# COM_CAT_21        0.000000      0
# COM_CAT_22        0.000000      0
# COM_CAT_23        0.000000      0
# COM_CAT_24        0.000000      0
# COM_CAT_25        0.000000      0
# COM_CAT_26        0.000000      0
# COM_CAT_27        0.000000      0
# COM_CAT_28        0.000000      0
# COM_CAT_29        0.000000      0
# COM_CAT_30        0.000000      0
# COM_CAT_31        0.000000      0
# COM_CAT_32        0.000000      0
# COM_CAT_33        0.000000      0
# COM_CAT_34        0.032556   3464

# %% [markdown]
# Duplicates by SK_ID

# %% [markdown]
# Гипотеза - возможно стоит группировать и брать средние за 12 месяцев!

# %%
df[df.SK_ID == 1827].sort_values('SNAP_DATE',ascending=False) #3608
# Out:
#        SK_ID  CSI CONTACT_DATE SNAP_DATE  COM_CAT_1  COM_CAT_2  COM_CAT_3  \
# 18650   1827  1.0        01.05  01.12.01          6         25          4
# 18643   1827  1.0        01.05  01.11.01          6         25          4
# 18645   1827  1.0        01.05  01.10.01          6         25          4
# 18647   1827  1.0        01.05  01.09.01          6         25          4
# 18642   1827  1.0        01.05  01.08.01          6         25          4
# 18644   1827  1.0        01.05  01.07.01          6         25          3
# 18641   1827  1.0        01.05  01.06.01          6         25          3
# 18649   1827  1.0        01.05  01.05.02          6         25          5
# 18652   1827  1.0        01.05  01.04.02          6         25          5
# 18646   1827  1.0        01.05  01.03.02          6         25          5
# 18648   1827  1.0        01.05  01.02.02          6         25          5
# 18651   1827  1.0        01.05  01.01.02          6         25          4
#
#        BASE_TYPE  ACT  ARPU_GROUP  COM_CAT_7  COM_CAT_8  DEVICE_TYPE_ID  \
# 18650          2    1         7.0          1      756.0             5.0
# 18643          2    1         6.0          1      756.0             5.0
# 18645          2    1         6.0          1      756.0             5.0
# 18647          2    1         6.0          1      756.0             5.0
# 18642          2    1         7.0          1      756.0             5.0
# 18644          2    1         6.0          1      756.0             5.0
# 18641          2    1         6.0          1      756.0             5.0
# 18649          2    1         9.0          1      756.0             5.0
# 18652          2    1         8.0          1      756.0             5.0
# 18646          2    1         7.0          1      756.0             5.0
# 18648          2    1         7.0          1      756.0             5.0
# 18651          2    1         6.0          1      756.0             5.0
#
#        INTERNET_TYPE_ID   REVENUE       ITC       VAS  RENT_CHANNEL  ROAM  \
# 18650               2.0  0.121161  0.009813  0.084795      0.055439   0.0
# 18643               2.0  0.119344  0.003228  0.084640      0.055376   0.0
# 18645               2.0  0.120023  0.009799  0.084552      0.055601   0.0
# 18647               2.0  0.119355  0.004656  0.085421      0.055995   0.0
# 18642               2.0  0.120577  0.009197  0.085008      0.056170   0.0
# 18644               2.0  0.119358  0.003931  0.085070      0.055565   0.0
# 18641               2.0  0.117526  0.001007  0.084167      0.055722   0.0
# 18649               2.0  0.128572  0.001103  0.084167      0.057550   0.0
# 18652               2.0  0.128366  0.015456  0.086449      0.056589   0.0
# 18646               2.0  0.123162  0.008165  0.089613      0.055791   0.0
# 18648               2.0  0.120621  0.003567  0.086892      0.056338   0.0
# 18651               2.0  0.118292  0.002282  0.084358      0.056098   0.0
#
#            COST  COM_CAT_17  COM_CAT_18  COM_CAT_19  COM_CAT_20  COM_CAT_21  \
# 18650  0.005284         0.0         0.0    0.026212    0.702234    0.019298
# 18643  0.004599         0.0         0.0    0.026212    0.702125    0.019298
# 18645  0.005280         0.0         0.0    0.026212    0.701837    0.019298
# %%
df['Year_Snap_Date']=df.SNAP_DATE.dt.year #encode 2017 as 0 and 2018 as 1
df['Month_Snap_Date']=df.SNAP_DATE.dt.month
df['Year_Snap_Date'] = pd.Categorical(df['Year_Snap_Date'])
df['Year_Snap_Date'] = df['Year_Snap_Date'].cat.codes

# %%
df.drop(['SNAP_DATE'],axis = 1 , inplace = True)

# %% [markdown]
# Посмотрим на величину COM_CAT_24.

# %%
df.COM_CAT_24.unique()
# Out:
# array(['31.12', '06.05', '27.05', '30.05', '28.05', '29.05', '23.05',
#        '24.05', '12.04', '15.04', '19.04', '23.04', '22.04', '08.04'],
#       dtype=object)

# %%
df.COM_CAT_24.value_counts()
# стоит обратить внимание, на то значения когда не 31.12
# Out:
# 31.12    106387
# 15.04         1
# 22.04         1
# 30.05         1
# 24.05         1
# 23.04         1
# 12.04         1
# 29.05         1
# 08.04         1
# 19.04         1
# 27.05         1
# 06.05         1
# 23.05         1
# 28.05         1
# Name: COM_CAT_24, dtype: int64

# %% [markdown]
# Дропнем эту таблицу, т.к. она по сути состоит только из одного значения.

# %%
df.drop('COM_CAT_24', axis = 1, inplace = True)

# %% [markdown]
# Посмотрим теперь на Contact Date.

# %%
df.CONTACT_DATE = pd.to_datetime(df.CONTACT_DATE, format='%d.%m')

# %%
df['Month_CONTACT_DATE']=df.CONTACT_DATE.dt.month#encode Year 2004 as 0 and 2005 as 1
df['Day_CONTACT_DATE']=df.CONTACT_DATE.dt.day

# %%
df.CONTACT_DATE.unique()
# Out:
# array(['1900-05-04T00:00:00.000000000', '1900-05-21T00:00:00.000000000',
#        '1900-05-27T00:00:00.000000000', '1900-05-08T00:00:00.000000000',
#        '1900-05-06T00:00:00.000000000', '1900-05-03T00:00:00.000000000',
#        '1900-05-30T00:00:00.000000000', '1900-05-29T00:00:00.000000000',
#        '1900-05-26T00:00:00.000000000', '1900-05-02T00:00:00.000000000',
#        '1900-05-09T00:00:00.000000000', '1900-05-17T00:00:00.000000000',
#        '1900-05-12T00:00:00.000000000', '1900-05-15T00:00:00.000000000',
#        '1900-05-20T00:00:00.000000000', '1900-05-01T00:00:00.000000000',
#        '1900-05-10T00:00:00.000000000', '1900-05-25T00:00:00.000000000',
#        '1900-05-23T00:00:00.000000000', '1900-05-31T00:00:00.000000000',
#        '1900-05-28T00:00:00.000000000', '1900-05-18T00:00:00.000000000',
#        '1900-05-05T00:00:00.000000000', '1900-05-24T00:00:00.000000000',
#        '1900-05-19T00:00:00.000000000', '1900-05-07T00:00:00.000000000',
#        '1900-05-14T00:00:00.000000000', '1900-05-11T00:00:00.000000000',
#        '1900-05-13T00:00:00.000000000', '1900-05-22T00:00:00.000000000',
#        '1900-05-16T00:00:00.000000000', '1900-04-02T00:00:00.000000000',
#        '1900-04-18T00:00:00.000000000', '1900-04-14T00:00:00.000000000',
#        '1900-04-03T00:00:00.000000000', '1900-04-19T00:00:00.000000000',
#        '1900-04-09T00:00:00.000000000', '1900-04-12T00:00:00.000000000',
#        '1900-04-23T00:00:00.000000000', '1900-04-04T00:00:00.000000000',
#        '1900-04-22T00:00:00.000000000', '1900-04-07T00:00:00.000000000',
#        '1900-04-16T00:00:00.000000000', '1900-04-01T00:00:00.000000000',
#        '1900-04-11T00:00:00.000000000', '1900-04-24T00:00:00.000000000',
#        '1900-04-26T00:00:00.000000000', '1900-04-20T00:00:00.000000000',
#        '1900-04-15T00:00:00.000000000', '1900-04-25T00:00:00.000000000',
#        '1900-04-05T00:00:00.000000000', '1900-04-10T00:00:00.000000000',
#        '1900-04-13T00:00:00.000000000', '1900-04-17T00:00:00.000000000',
#        '1900-04-21T00:00:00.000000000', '1900-04-27T00:00:00.000000000',
#        '1900-04-28T00:00:00.000000000', '1900-04-06T00:00:00.000000000',
#        '1900-04-08T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
df.CONTACT_DATE.value_counts()
# Out:
# 1900-05-12    2858
# 1900-04-24    2436
# 1900-04-07    2409
# 1900-04-09    2365
# 1900-05-08    2347
# 1900-04-13    2337
# 1900-04-05    2302
# 1900-04-23    2276
# 1900-05-13    2267
# 1900-04-11    2185
# 1900-04-04    2180
# 1900-04-14    2164
# 1900-04-20    2153
# 1900-04-06    2131
# 1900-04-25    2070
# 1900-04-17    2052
# 1900-04-26    2049
# 1900-04-27    1995
# 1900-05-17    1990
# 1900-05-09    1985
# 1900-04-21    1952
# 1900-04-12    1938
# 1900-05-02    1937
# 1900-04-19    1932
# 1900-05-11    1906
# 1900-04-16    1897
# 1900-04-15    1889
# 1900-05-04    1878
# 1900-04-18    1878
# 1900-05-05    1872
# 1900-05-10    1849
# 1900-05-14    1831
# 1900-04-03    1813
# 1900-04-22    1795
# 1900-04-01    1792
# 1900-04-10    1767
# 1900-05-22    1760
# 1900-05-03    1725
# 1900-05-01    1715
# 1900-05-30    1689
# 1900-05-28    1687
# 1900-05-07    1679
# 1900-05-21    1672
# 1900-05-06    1665
# 1900-04-02    1651
# 1900-05-16    1644
# 1900-05-27    1622
# 1900-05-24    1555
# 1900-05-29    1548
# 1900-04-08    1474
# 1900-05-25    1449
# 1900-05-26    1396
# 1900-05-19    1319
# 1900-05-18    1254
# 1900-05-23     955
# 1900-05-31     912
# 1900-05-20     822
# 1900-04-28     435
# 1900-05-15     295
# Name: CONTACT_DATE, dtype: int64

# %%
df.drop('CONTACT_DATE', axis = 1, inplace = True)

# %%
df_num_features = df.select_dtypes([np.number]).columns

# %%
df_cat_features = df.select_dtypes([np.object,'datetime']).columns

# %% [markdown]
# Numerical features analyse.

# %%
df_good = df[df_num_features][df.CSI == 0]
df_bad = df[df_num_features][df.CSI == 1]

# %%
df_bad.describe() - df_good.describe()
# Out:
#               SK_ID      CSI     COM_CAT_1     COM_CAT_2     COM_CAT_3  \
# count -32553.000000 -32553.0 -32553.000000 -32553.000000 -32553.000000
# mean      12.121475      1.0      0.039435     -1.447129     -0.044154
# std       -8.335166      0.0      0.214598      0.153809     -0.136852
# min        4.000000      1.0      0.000000      0.000000      0.000000
# 25%      -22.250000      1.0      0.000000     -1.000000      0.000000
# mean       0.003268     -0.000575     -0.000198      0.004449     -0.000040
# std        0.003292     -0.006966     -0.001487      0.005595     -0.003152
# min        0.000000      0.000000      0.000000      0.000000     -0.007143
# 25%        0.000455      0.000000      0.000000      0.000975      0.000000
# 50%        0.002052      0.000294      0.000000      0.004498      0.000000
# 75%        0.005066      0.000891      0.000533      0.006571      0.000000
# max       -0.034857     -0.754211     -0.444073      0.269832     -0.257584
#
#          COM_CAT_33    COM_CAT_34  Year_Snap_Date  Month_Snap_Date  \
# count -32553.000000 -31378.000000   -32553.000000    -32553.000000
# mean       0.000461     -0.173638       -0.003299         0.014477
# std        0.002155     -0.033193       -0.000428        -0.001503
# min       -0.090927      0.000000        0.000000         0.000000
# 25%        0.000000      0.000000        0.000000         0.000000
# 50%        0.000000      0.000000        0.000000         0.000000
# 75%        0.000000      0.000000        0.000000         0.000000
# max       -0.114306      0.000000        0.000000         0.000000
#
#        Month_CONTACT_DATE  Day_CONTACT_DATE
# count            -32553.0     -32553.000000
# mean                  0.0         -0.066970
# std                   0.0         -0.149023
# min                   0.0          0.000000
# 25%                   0.0          0.000000
# 50%                   0.0          0.000000
# 75%                   0.0         -1.000000
# max                   0.0          0.000000
#
# [8 rows x 39 columns]

# %%
df[df_num_features].hist(figsize=(20, 20), bins='doane', xlabelsize=8, ylabelsize=8);

# %% [markdown]
# Countplots

# %%
for i, col in enumerate(df[df_num_features].columns.drop([target,'SK_ID'])):
    print(df[col].value_counts(normalize = True))
# Out:
# 3    0.163976
# 5    0.158524
# 4    0.147650
# 8    0.126137
# 7    0.108327
# 1    0.103835
# 2    0.098064
# 6    0.093487
# Name: COM_CAT_1, dtype: float64
# 30    0.103835
# 60    0.036513
# 32    0.027209
# 25    0.019737
# 43    0.018853
# 63    0.016795
# 77    0.014596
# 54    0.014549
# 28    0.014154
# 66    0.014135
# 40    0.014107
# 52    0.013976
# 15    0.013759
# 57    0.013647
# 68    0.013430
# 3     0.013299
# 65    0.012932
# 53    0.012679
# 24    0.012669
# 34    0.012641
# 4     0.011701
# 82    0.011476
# 59    0.011429
# 33    0.010883
# 20    0.010855
# 55    0.010855
# 58    0.010846
# 44    0.010836
# 14    0.010799
# 62    0.010658
#         ...
# 7     0.009868
# 18    0.009859
# 10    0.009840
# 23    0.009774
# 19    0.009709
# 78    0.009680
# 35    0.009521
# 11    0.009511
# 50    0.009483
# 2     0.009445
# 47    0.009398
# 5     0.009398
# 17    0.009342
# 31    0.009305
# 46    0.009267
# 22    0.009239
# 74    0.009192
# 49    0.009192
# 37    0.009098
# 64    0.009088
# 36    0.008957
# 76    0.008769
# 79    0.008562
# 73    0.007838
# 29    0.006184
# 81    0.004126
# 70    0.004032
# 1     0.001485
# 42    0.000489
# 67    0.000113
# Name: COM_CAT_2, Length: 83, dtype: float64
# 5     0.693731
# 1     0.050583
# 2     0.047707
# 3     0.047387
# 4     0.045695
# 17    0.011034
# 9     0.010987
# 10    0.010169
# 11    0.009756
# 12    0.009558
# 4     0.038139
# 17    0.037989
# 14    0.037547
# 24    0.037509
# 8     0.035912
# 6     0.035677
# 21    0.034060
# 27    0.033994
# 10    0.033985
# 2     0.033722
# 22    0.033412
# 16    0.033280
# 3     0.033252
# 25    0.033073
# 1     0.032961
# 26    0.032378
# 19    0.030555
# 23    0.030367
# 18    0.029436
# 20    0.027961
# 15    0.020526
# 28    0.019944
# 30    0.015874
# 29    0.014549
# 31    0.008571
# Name: Day_CONTACT_DATE, dtype: float64

# %% [markdown]
# CHECK OUTLIERS FIRST!

# %% [markdown]
# Корреляции.

# %%
df_feature_corr = df.drop(target, axis = 1).corr(method = 'pearson')

plt.figure(figsize=(25, 15))
sns.heatmap(df_feature_corr[abs(df_feature_corr) > 0.6], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
#df.drop('COM_CAT_28',axis = 1, inplace = True)

# %%
#df.drop('COM_CAT_23',axis = 1, inplace = True)

# %%
#df.drop('COM_CAT_22',axis = 1, inplace = True)

# %%
#df.drop('COM_CAT_27',axis = 1, inplace = True) признак нужный

# %%
df.drop('Month_CONTACT_DATE',axis = 1, inplace = True)# дроп этой фичи улучшает скор

# %%
df.drop('COM_CAT_26',axis = 1, inplace = True)# дроп этой фичи улучшает скор

# %% [markdown]
# Выводы из корреляций:
# 1. Com_cat_3 и Base type коррелированы отрицательно.
# 2. ARPU Group сильнее всего связан с Revenue и Com Cat 23. ARPU = Total Revenue / # of Users.
# 3. Device type id and internet type id коррелированы отрицательно.
# 4. Revenue связан с ARPU Group и Com Cat 20, Com Cat 22 и Com Cat 23.
# 5. ITC с Com Cat 28.
# 6. ROAM с COST.
# 7. COST c Com Cat 28.
# 8. Com cat 20 c Com Cat 22 и Com Cat 23.
#
# Обратить внимание на VAS - Value Added Services услуги, приносящие дополнительный доход.
#
#
# Из анализа количества переменных в классах можно выделить:
#
# Name: COM_CAT_25, dtype: int64
#
#     1    47404
#     0        7
#
# Name: COM_CAT_26, dtype: int64
#
#     1    46862
#     0      549
#
#
# Относительно
# - base type
# - act
# - com cat 17 and 18 19 - обратить внимание
# - COM_CAT_20
# - COM_CAT_25
# - COM_CAT_26
# - COM_CAT_29

# %%
df[df.COM_CAT_25 == 0]
# Out:
#        SK_ID  CSI  COM_CAT_1  COM_CAT_2  COM_CAT_3  BASE_TYPE  ACT  \
# 9253     905  0.0          4         59          1          2    1
# 9457     923  0.0          4         70          5          2    1
# 17274   1694  1.0          7         26         12          1    1
# 17644   1729  0.0          1         30          4          2    1
# 18225   1785  1.0          4         36          5          2    1
# 18342   1796  0.0          5         60          5          2    1
# 45837   4550  0.0          1         30         10          1    1
# 7542    7071  NaN          1         30          2          2    1
# 12110   8644  NaN          1         30          2          2    1
# 17673   6666  NaN          1         30          3          2    1
# 28274   8362  NaN          1         30         12          1    1
# 40587   9552  NaN          4         51          6          2    1
# 57328   7401  NaN          7         77          5          2    1
#
# 18342    0.122149           0           1    0.013793    0.010987    0.000036
# 45837    0.109409           0           1    0.000000    0.000000    0.000000
# 7542     0.109461           0           1    0.010230    0.001375    0.000406
# 12110    0.115518           0           1    0.019653    0.017824    0.000994
# 17673    0.109409           0           1    0.006360    0.000000    0.000000
# 28274    0.109409           0           1    0.003206    0.000000    0.000000
# 40587    0.118111           0           1    0.020362    0.000000    0.000013
# 57328    0.109409           0           1    0.019162    0.006956    0.000000
#
#        COM_CAT_30  COM_CAT_31  COM_CAT_32  COM_CAT_33  COM_CAT_34  \
# 9253     0.000000    0.001175    0.027579    0.103896        10.0
# 9457     0.000000    0.005066    0.027579    0.103896        10.0
# 17274    0.000004    0.016221    0.027605    0.110157         9.0
# 17644    0.002276    0.047276    0.027882    0.106706         9.0
# 18225    0.000000    0.005527    0.027579    0.103896        10.0
# 18342    0.013846    0.015245    0.027579    0.103896         2.0
# 45837    0.000000    0.000000    0.027579    0.103896         NaN
# 7542     0.000000    0.007771    0.027579    0.103896         2.0
# 12110    0.000000    0.042777    0.027579    0.103896         7.0
# 17673    0.000000    0.005149    0.027579    0.103896        10.0
# 28274    0.000000    0.003895    0.027579    0.103896         9.0
# 40587    0.000000    0.023689    0.027579    0.103896         9.0
# 57328    0.001854    0.021962    0.027579    0.103896         2.0
#
#        Year_Snap_Date  Month_Snap_Date  Month_CONTACT_DATE  Day_CONTACT_DATE
# 9253                1                5                   5                 2
# 9457                1                5                   5                26
# 17274               1                5                   5                14
# 17644               1                5                   5                 1
# 18225               1                5                   5                 7
# 18342               1                5                   5                 6
# 45837               1                5                   5                25
# 7542                1                4                   4                 7
# 12110               1                4                   4                25
# 17673               1                4                   4                13
# 28274               1                4                   4                 3
# 40587               1                4                   4                 7
# 57328               1                4                   4                 1
#
# [13 rows x 39 columns]

# %%
df.drop('COM_CAT_25',axis = 1, inplace = True)

# %%
#df_union[df_union.COM_CAT_26 == 0]

# %% [markdown]
# Что характерно, для всех значений COM_CAT_26=0 COM_CAT_34 в основном отсутсвует.

# %% [markdown]
# #### Target analysis.

# %%
df.CSI.value_counts()
# Out:
# 0.0    39982
# 1.0     7429
# Name: CSI, dtype: int64

# %% [markdown]
# Посмотрим на вид целевой переменной в зависимости от других признаков.

# %%
plt.figure(figsize=(25, 5))
sns.boxplot(x=df[target],y=df.COST, hue='CSI', data=df)
plt.show()

# %%
df[df.COST == 1]#скорее всего выброс
# Out:
#        SK_ID  CSI  COM_CAT_1  COM_CAT_2  COM_CAT_3  BASE_TYPE  ACT  \
# 13735   1344  0.0          1         30          3          2    1
#
#        ARPU_GROUP  COM_CAT_7  COM_CAT_8  DEVICE_TYPE_ID  INTERNET_TYPE_ID  \
# 13735        12.0          1      126.0             5.0               2.0
#
#         REVENUE       ITC       VAS  RENT_CHANNEL  ROAM  COST  COM_CAT_17  \
# 13735  0.314323  0.002431  0.084167      0.063686   1.0   1.0         0.0
#
#        COM_CAT_18  COM_CAT_19  COM_CAT_20  COM_CAT_21  COM_CAT_22  COM_CAT_23  \
# 13735         0.0    0.026212         0.0    0.019298         0.0    0.315647
#
#        COM_CAT_26  COM_CAT_27  COM_CAT_28  COM_CAT_29  COM_CAT_30  COM_CAT_31  \
# 13735           1    0.002878    0.002431    0.003612    0.045526    0.005358
#
#        COM_CAT_32  COM_CAT_33  COM_CAT_34  Year_Snap_Date  Month_Snap_Date  \
# 13735    0.058584    0.103896         2.0               0                8
#
#        Month_CONTACT_DATE  Day_CONTACT_DATE
# 13735                   5                29

# %%
sns.boxplot(x=df[target],y=df.COM_CAT_1, hue='CSI', data=df)
#sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips);

# %%
sns.boxplot(x=df[target],y=df.COM_CAT_2, hue='CSI', data=df)

# %%
sns.boxplot(x=df[target],y=df.VAS, hue='CSI', data=df)
# check outlier

# %%
sns.boxplot(x=df[target],y=df.COM_CAT_20, hue='CSI', data=df) #check more

# %%
sns.boxplot(x=df[target],y=df.COM_CAT_29, hue='CSI', data=df) #check more

# %%
df[df.COM_CAT_29 == 1]
# Out:
#        SK_ID  CSI  COM_CAT_1  COM_CAT_2  COM_CAT_3  BASE_TYPE  ACT  \
# 37081   3693  0.0          5         83          4          2    1
#
#        ARPU_GROUP  COM_CAT_7  COM_CAT_8  DEVICE_TYPE_ID  INTERNET_TYPE_ID  \
# 37081        10.0          1     1520.0             5.0               2.0
#
#         REVENUE       ITC       VAS  RENT_CHANNEL  ROAM      COST  COM_CAT_17  \
# 37081  0.133257  0.001914  0.085238      0.141942   0.0  0.011334         0.0
#
#        COM_CAT_18  COM_CAT_19  COM_CAT_20  COM_CAT_21  COM_CAT_22  COM_CAT_23  \
# 37081         0.0    0.026212    0.701814    0.019298    0.701814    0.133496
#
#        COM_CAT_26  COM_CAT_27  COM_CAT_28  COM_CAT_29  COM_CAT_30  COM_CAT_31  \
# 37081           1    0.004466     0.00183         1.0         0.0    0.010005
#
#        COM_CAT_32  COM_CAT_33  COM_CAT_34  Year_Snap_Date  Month_Snap_Date  \
# 37081    0.027579    0.103896         2.0               1                1
#
#        Month_CONTACT_DATE  Day_CONTACT_DATE
# 37081                   5                22

# %% [markdown]
# Проведем аггрегацию различных фич по SK_ID.

# %%
#df.describe()

# %%
#df_aggregate_test = df[(df.SK_ID == 2) | (df.SK_ID == 3339)]

# %%
# check what if in some variables customer can have more than value of characteristics
# check for ARPU_GROUP
#transfrom quantiles
#df.COM_CAT_26.value_counts()

# %%
df.Month_CONTACT_DATE.value_counts()
# Out:
# 4    55317
# 5    51083
# Name: Month_CONTACT_DATE, dtype: int64

# %%
plt.figure(figsize=(25, 15))
sns.boxplot(x=df.Day_CONTACT_DATE,y=df.SK_ID, hue='CSI', data=df, )
plt.legend(loc='upper left')

# %% [markdown]
# Факты:
#     - Base type = 1 , старая абонентская база более недовольны
#     - COM_CAT_1 = 1,3,8 более недовольны
#     - ARPU_GROUP 1,2,5,11,12 более недовольны
#     - COM_CAT_34 есть несколько недовольных групп 1,5,8,9.
#     - COM_CAT_26 равные 0 более недовольны
#     - DEVICE_TYPE_ID 7,8 недовольны более всего
#     - VAS можно заенкодить по нескольким основным значениям
#     - Rent аналогично VAS, Roam,COM_CAT_17,COM_CAT_18,COM_CAT_19,COM_CAT_29,COM_CAT_30,COM_CAT_32,COM_CAT_33 также
#     - COM_CAT_20,COM_CAT_21,COM_CAT_22,COM_CAT_23, COM_CAT_27,COM_CAT_28,COM_CAT_31 - непонятно
#     - COM_CAT_25 отдельно посмотреть, там все NAN или ..?
#     - Contact Day очень сильно влияет!

# %%
#df.sort_values(by = 'SK_ID')

# %% [markdown]
# А если посмотреть датасеты на примере нескольких SK_ID но разделению трейн-тест.

# %%
test_split_index = 47411

# %%
df_train = df[:test_split_index]
df_test = df[test_split_index:]

# %%
#split_index
print ("   train df", "           test df")
print (pd.concat([df_train.Month_CONTACT_DATE.value_counts() ,df_test.Month_CONTACT_DATE.value_counts() ],axis=1))

print (pd.concat([df_train.Day_CONTACT_DATE.value_counts() ,df_test.Day_CONTACT_DATE.value_counts() ],axis=1))
# Out:
#    train df            test df
#    Month_CONTACT_DATE  Month_CONTACT_DATE
# 4                 NaN               55317
# 5             47411.0                3672
#     Day_CONTACT_DATE  Day_CONTACT_DATE
# 1               1589              1918
# 2               1758              1830
# 3               1664              1874
# 4               1776              2282
# 5               1728              2446
# 6               1533              2263
# 7               1535              2553
# 8               2215              1606
# 9               1855              2495
# 10              1634              1982
# 11              1817              2274
# 12              2682              2114
# 13              2141              2463
# 14              1742              2253
# 15               271              1913
# 16              1551              1990
# 17              1866              2176
# 18              1106              2026
# 19              1091              2160
# 20               777              2198
# 21              1584              2040
# 22              1615              1940
# 23               894              2337
# 24              1446              2545
# 25              1357              2162
# 26              1228              2217
# 27              1542              2075
# 28              1564               558
# 29              1385               163
# 30              1563               126
# 31               902                10

# %%
df_train[df_train.SK_ID == 3393].sort_values(by = ['Year_Snap_Date','Month_Snap_Date'])
# Out:
#        SK_ID  CSI  COM_CAT_1  COM_CAT_2  COM_CAT_3  BASE_TYPE  ACT  \
# 34113   3393  1.0          8         44          5          2    1
# 34112   3393  1.0          8         44          5          2    1
# 34115   3393  1.0          8         44          5          2    1
# 34114   3393  1.0          8         44          5          2    1
# 34123   3393  1.0          8         44          5          2    1
# 34118   3393  1.0          8         44          5          2    1
# 34116   3393  1.0          8         44          5          2    1
# 34120   3393  1.0          8         44          5          2    1
# 34122   3393  1.0          8         44          5          2    1
# 34117   3393  1.0          8         44          5          2    1
# 34119   3393  1.0          8         44          5          2    1
# 34121   3393  1.0          8         44          5          2    1
#
#        ARPU_GROUP  COM_CAT_7  COM_CAT_8  DEVICE_TYPE_ID  INTERNET_TYPE_ID  \
# 34113        12.0          3      558.0             5.0               2.0
# 34112        12.0          3     1520.0             5.0               2.0
# 34115        12.0          3      558.0             5.0               2.0
# 34114        12.0          2      558.0             5.0               2.0
# 34123        12.0          2      558.0             5.0               2.0
# 34118        11.0          2      558.0             5.0               2.0
# 34116         9.0          2      558.0             5.0               2.0
# 34120        10.0          2      558.0             5.0               2.0
#        COM_CAT_32  COM_CAT_33  COM_CAT_34  Year_Snap_Date  Month_Snap_Date  \
# 34113    0.027579    0.103896         2.0               0                6
# 34112    0.027579    0.103896         2.0               0                7
# 34115    0.027579    0.103896         2.0               0                8
# 34114    0.027579    0.103896         2.0               0                9
# 34123    0.027579    0.103896         2.0               0               10
# 34118    0.027579    0.103896         2.0               0               11
# 34116    0.027579    0.103896         2.0               0               12
# 34120    0.027579    0.103896         2.0               1                1
# 34122    0.027579    0.103896         2.0               1                2
# 34117    0.027579    0.103896         2.0               1                3
# 34119    0.027579    0.103896         2.0               1                4
# 34121    0.027579    0.103896         2.0               1                5
#
#        Month_CONTACT_DATE  Day_CONTACT_DATE
# 34113                   5                 1
# 34112                   5                 1
# 34115                   5                 1
# 34114                   5                 1
# 34123                   5                 1
# 34118                   5                 1
# 34116                   5                 1
# 34120                   5                 1
# 34122                   5                 1
# 34117                   5                 1
# 34119                   5                 1
# 34121                   5                 1

# %%
df_test[df_test.SK_ID == 6954].sort_values(by = ['Year_Snap_Date','Month_Snap_Date'])
# Out:
#        SK_ID  CSI  COM_CAT_1  COM_CAT_2  COM_CAT_3  BASE_TYPE  ACT  \
# 34765   6954  NaN          8         44         17          1    1
# 34766   6954  NaN          8         44          9          1    1
# 34774   6954  NaN          8         44         10          1    1
# 34767   6954  NaN          8         44         11          1    1
# 34764   6954  NaN          8         44         12          1    1
# 34770   6954  NaN          8         44         13          1    1
# 34768   6954  NaN          8         44         14          2    1
# 34773   6954  NaN          8         44         15          2    1
# 34772   6954  NaN          8         44         16          2    1
# 34769   6954  NaN          8         44          6          2    1
# 34771   6954  NaN          8         44          7          2    1
#
#        ARPU_GROUP  COM_CAT_7  COM_CAT_8  DEVICE_TYPE_ID  INTERNET_TYPE_ID  \
# 34765         5.0          3        NaN             3.0               3.0
# 34766         7.0          3        NaN             3.0               3.0
# 34774         7.0          3        NaN             3.0               3.0
# 34767        10.0          3        NaN             3.0               3.0
# 34764        12.0          3        NaN             3.0               3.0
# 34770         5.0          3        NaN             3.0               3.0
# 34768         7.0          3     1206.0             3.0               3.0
# 34773         7.0          3        NaN             3.0               3.0
# 34772         7.0          3     1543.0             3.0               3.0
# 34769         8.0          3     1543.0             3.0               3.0
# 34771        10.0          3     1543.0             3.0               3.0
#
#         REVENUE       ITC       VAS  RENT_CHANNEL  ROAM      COST  COM_CAT_17  \
# 34765  0.112960  0.004472  0.084167      0.054992   0.0  0.004664    0.000000
# 34766  0.122834  0.007605  0.095102      0.055002   0.0  0.005701    0.044996
# 34774  0.122744  0.002831  0.094732      0.054975   0.0  0.005189    0.063112
# 34767  0.134820  0.019066  0.103794      0.055116   0.0  0.007447    0.107933
# 34764  0.140993  0.036439  0.101207      0.055145   0.0  0.009049    0.084320
# 34770  0.113814  0.000318  0.091089      0.054987   0.0  0.004695    0.000000
# 34768  0.122479  0.000605  0.098833      0.055030   0.0  0.005235    0.002415
# 34773  0.120981  0.000000  0.096945      0.055037   0.0  0.005051    0.000000
# 34772  0.124113  0.002091  0.100117      0.055098   0.0  0.005476    0.000000
# 34769  0.125325  0.001630  0.099024      0.055102   0.0  0.005358    0.000000
# 34771  0.132884  0.011556  0.096891      0.055121   0.0  0.006230    0.000000
#
#        COM_CAT_18  COM_CAT_19  COM_CAT_20  COM_CAT_21  COM_CAT_22  COM_CAT_23  \
# 34765         0.0    0.026212    0.699823    0.019298    0.699823    0.113037
# 34766         0.0    0.026212    0.702501    0.022391    0.700864    0.122304
# 34774         0.0    0.026212    0.702866    0.023637    0.700570    0.123945
# 34767         0.0    0.026212    0.705375    0.026719    0.701448    0.134979
# 34764         0.0    0.026212    0.706312    0.025095    0.703244    0.139224
# 34770         0.0    0.026212    0.700100    0.019298    0.700100    0.114547
# 34768         0.0    0.026212    0.702737    0.019464    0.702649    0.123955
# 34773         0.0    0.026212    0.702352    0.019298    0.702352    0.122453
# 34772         0.0    0.026212    0.703126    0.019298    0.703126    0.125534
# 34769         0.0    0.026212    0.703645    0.019298    0.703645    0.125734
# 34771         0.0    0.026212    0.705635    0.019298    0.705635    0.126749
#
#        COM_CAT_26  COM_CAT_27  COM_CAT_28  COM_CAT_29  COM_CAT_30  COM_CAT_31  \
# 34765           0    0.006011    0.004472         0.0         0.0    0.006368
# 34766           1    0.008781    0.007605         0.0         0.0    0.008375
# 34774           1    0.001206    0.002831         0.0         0.0    0.004110
# 34767           1    0.005907    0.019066         0.0         0.0    0.023749
# 34764           1    0.014411    0.036439         0.0         0.0    0.040759
# 34770           1    0.003152    0.000318         0.0         0.0    0.004880
# 34768           1    0.000000    0.000605         0.0         0.0    0.015164
# 34773           1    0.000000    0.000000         0.0         0.0    0.015534
# 34772           1    0.000259    0.002091         0.0         0.0    0.027188
# 34769           1    0.004700    0.001630         0.0         0.0    0.024408
# 34771           1    0.032814    0.011556         0.0         0.0    0.032812
#
#        COM_CAT_32  COM_CAT_33  COM_CAT_34  Year_Snap_Date  Month_Snap_Date  \
# 34765    0.027579    0.103896         NaN               0                6
# 34766    0.027579    0.103896         NaN               0                7
# 34774    0.027579    0.103896         NaN               0                8
# 34767    0.027579    0.103896        10.0               0                9
# 34764    0.027579    0.103896        10.0               0               10
# 34770    0.027579    0.103896        10.0               0               11
# 34768    0.027579    0.103896        10.0               0               12
# 34773    0.027579    0.103896         3.0               1                1
# 34772    0.027579    0.103896         3.0               1                2
# 34769    0.027579    0.103896         3.0               1                3
# 34771    0.027579    0.103896         3.0               1                4
#
#        Month_CONTACT_DATE  Day_CONTACT_DATE
# 34765                   4                 4
# 34766                   4                 4
# 34774                   4                 4
# 34767                   4                 4
# 34764                   4                 4
# 34770                   4                 4
# 34768                   4                 4
# 34773                   4                 4
# 34772                   4                 4
# 34769                   4                 4
# 34771                   4                 4

# %% [markdown]
# Т.е. получается, что мы тренируемся на данных за Май(5 месяц опроса), тогда как предсказать должны за клиентов по апрелю(4 месяц опроса).
#
# Таким образом можно выдвинуть гипотезу, что для получения наилучших результатов будем аггрегировать:
#  - данные из сторонних таблиц сначала сгруппируем по месяцу и подключим к основной таблице
#  -
#
# Не стоит забывать про одну человеческую особенность - врятли абонент будет помнить про то, что было год назад и поэтому стоит учитывать, что возможно будут важны данные только за последние 3 месяца (как в таблице bs_consumption).
#
# ВОЗМОЖНО: следует откинуть все кроме последнего месяца и дня опроса и это даст наилучший результат.

# %% [markdown]
# Зададим функцию, которая собирает количество лет, за которые проводился сбор данных.

# %%
def get_len_unique(test_obj):
    return len(test_obj.unique())

# %%
df = df.groupby('SK_ID',sort=False,as_index = False).agg({
    'CSI' : ['mean'],
    'Year_Snap_Date': [get_len_unique],
    'Month_Snap_Date': 'count',
    #'Month_CONTACT_DATE' : 'first',
    'Day_CONTACT_DATE' : 'first',
    'COM_CAT_1': ['mean'],
    'COM_CAT_2': 'mean', 
    'COM_CAT_3' :'mean',
    'BASE_TYPE' : 'first',
    'ACT' : 'median',
    'ARPU_GROUP' : 'mean',
    'COM_CAT_7': 'first',
    'COM_CAT_8' : 'mean',
    'DEVICE_TYPE_ID' : 'first',
    'INTERNET_TYPE_ID' : 'first', 
    'REVENUE' : 'mean',
    'ITC' : 'mean',
    'VAS' : 'mean',
    'RENT_CHANNEL' : 'mean',
    'ROAM' : 'mean',
    'COST' : 'mean',
    'COM_CAT_17' : 'mean',
    'COM_CAT_18' : 'mean',
    'COM_CAT_19' : 'mean',
    'COM_CAT_20' : 'mean',
    'COM_CAT_21' : 'mean',
    'COM_CAT_22' : 'mean',
    'COM_CAT_23' : 'mean',
    #'COM_CAT_26' : 'mean',
    'COM_CAT_27' : 'mean',
    'COM_CAT_28' : 'mean',
    'COM_CAT_29' : 'mean',
    'COM_CAT_30' : 'mean',
    'COM_CAT_31' : 'mean',
    'COM_CAT_32' : 'mean',
    'COM_CAT_33' : 'mean',
    'COM_CAT_34' : 'mean'
})

# %%
df.columns = df.columns.droplevel(1)

# %%
df.tail()
# Out:
#       SK_ID  CSI  Year_Snap_Date  Month_Snap_Date  Day_CONTACT_DATE  \
# 9438   8518  NaN               2               12                 3
# 9439   5739  NaN               2               12                 7
# 9440   6474  NaN               2               12                 4
# 9441   5430  NaN               2               12                11
# 9442   6156  NaN               2               12                14
#
#       COM_CAT_1  COM_CAT_2  COM_CAT_3  BASE_TYPE  ACT  ARPU_GROUP  COM_CAT_7  \
# 9438          1       30.0   5.000000          2  1.0    8.583333          1
# 9439          4        5.0   3.916667          2  1.0   10.083333          1
# 9440          5       48.0   5.000000          2  1.0    1.000000          4
# 9441          1       30.0   5.000000          2  1.0   12.000000          1
# 9442          4       54.0   5.000000          2  1.0    1.750000          3
#
#         COM_CAT_8  DEVICE_TYPE_ID  INTERNET_TYPE_ID   REVENUE       ITC  \
# 9438   184.000000             5.0               2.0  0.131094  0.023543
# 9439   847.833333             5.0               1.0  0.135449  0.007057
# 9440          NaN             3.0               3.0  0.108091  0.000000
# 9441   795.000000             5.0               2.0  0.166261  0.050674
# 9442  1324.000000             5.0               2.0  0.108708  0.000267
#
#            VAS  RENT_CHANNEL      ROAM      COST  COM_CAT_17  COM_CAT_18  \
# 9438  0.084629      0.055873  0.000474  0.007177         0.0    0.000000
# 9439  0.086837      0.055661  0.000000  0.005155         0.0    0.030009
# 9440  0.084167      0.054978  0.000000  0.004207         0.0    0.000000
# 9441  0.106172      0.057530  0.000000  0.011012         0.0    0.000000
# 9442  0.084188      0.055061  0.000000  0.004243         0.0    0.000000
#
#       COM_CAT_19  COM_CAT_20  COM_CAT_21  COM_CAT_22  COM_CAT_23  COM_CAT_27  \
# 9438    0.026212    0.704271    0.019298    0.704271    0.129728    0.012079
# 9439    0.026212    0.707372    0.019542    0.707332    0.130054    0.027225
# 9440    0.026212    0.698459    0.019298    0.698459    0.109529    0.000000
# 9441    0.026212    0.713701    0.019298    0.713701    0.156055    0.051584
# 9442    0.026212    0.698650    0.019298    0.698650    0.109638    0.002217
#
#       COM_CAT_28  COM_CAT_29  COM_CAT_30  COM_CAT_31  COM_CAT_32  COM_CAT_33  \
# 9438    0.023543    0.002219    0.003013    0.046954    0.027829    0.104284
# 9439    0.003949    0.009181    0.000000    0.085938    0.027591    0.104131
# 9440    0.000000    0.000000    0.000000    0.008167    0.027579    0.103896
# 9441    0.050674    0.009619    0.005251    0.078006    0.027858    0.104399
# 9442    0.000253    0.000121    0.000816    0.003885    0.027579    0.103896
#
#       COM_CAT_34
# 9438    7.250000
# 9439    2.000000
# 9440   10.000000
# 9441    2.000000
# 9442    7.666667

# %%
# посмотреть на csi больше 0 но меньше 1
df[(df.CSI < 1) & (df.CSI > 0)]
# Out:
# Empty DataFrame
# Columns: [SK_ID, CSI, Year_Snap_Date, Month_Snap_Date, Day_CONTACT_DATE, COM_CAT_1, COM_CAT_2, COM_CAT_3, BASE_TYPE, ACT, ARPU_GROUP, COM_CAT_7, COM_CAT_8, DEVICE_TYPE_ID, INTERNET_TYPE_ID, REVENUE, ITC, VAS, RENT_CHANNEL, ROAM, COST, COM_CAT_17, COM_CAT_18, COM_CAT_19, COM_CAT_20, COM_CAT_21, COM_CAT_22, COM_CAT_23, COM_CAT_27, COM_CAT_28, COM_CAT_29, COM_CAT_30, COM_CAT_31, COM_CAT_32, COM_CAT_33, COM_CAT_34]
# Index: []

# %%
print (pd.concat([1- df.count() / df.shape[0], df.isna().sum()],axis=1))
# Out:
#                          0     1
# SK_ID             0.000000     0
# CSI               0.552896  5221
# Year_Snap_Date    0.000000     0
# Month_Snap_Date   0.000000     0
# Day_CONTACT_DATE  0.000000     0
# COM_CAT_1         0.000000     0
# COM_CAT_2         0.000000     0
# COM_CAT_3         0.000000     0
# BASE_TYPE         0.000000     0
# ACT               0.000000     0
# ARPU_GROUP        0.000000     0
# COM_CAT_7         0.000000     0
# COM_CAT_8         0.022133   209
# DEVICE_TYPE_ID    0.000529     5
# INTERNET_TYPE_ID  0.000529     5
# REVENUE           0.000000     0
# ITC               0.000000     0
# VAS               0.000000     0
# RENT_CHANNEL      0.000000     0
# ROAM              0.000000     0
# COST              0.000000     0
# COM_CAT_17        0.000000     0
# COM_CAT_18        0.000000     0
# COM_CAT_19        0.000000     0
# COM_CAT_20        0.000000     0
# COM_CAT_21        0.000000     0
# COM_CAT_22        0.000000     0
# COM_CAT_23        0.000000     0
# COM_CAT_27        0.000000     0
# COM_CAT_28        0.000000     0
# COM_CAT_29        0.000000     0
# COM_CAT_30        0.000000     0
# COM_CAT_31        0.000000     0
# COM_CAT_32        0.000000     0
# COM_CAT_33        0.000000     0
# COM_CAT_34        0.035052   331

# %%
# аттачим к аггрегированному датасету
df = pd.merge(df,df_bsconsumption, on=['SK_ID'],how = 'left')

# %%
df.head()
# Out:
#    SK_ID  CSI  Year_Snap_Date  Month_Snap_Date  Day_CONTACT_DATE  COM_CAT_1  \
# 0      2  0.0               1                5                 4          7
# 1      3  0.0               2                9                21          4
# 2      4  0.0               2               12                27          8
# 3      5  0.0               2               12                 8          3
# 4      6  1.0               2               12                 6          5
#
#    COM_CAT_2  COM_CAT_3  BASE_TYPE  ACT  ARPU_GROUP  COM_CAT_7    COM_CAT_8  \
# 0       77.0  11.800000          1  1.0    8.600000          2  1318.000000
# 1       51.0  13.000000          1  1.0    8.222222          2   751.444444
# 2       12.0   3.833333          2  1.0    6.166667          3  1102.333333
# 3       79.0   2.000000          2  1.0    8.833333          1   110.000000
# 4       48.0   5.000000          2  1.0    2.166667          4   937.000000
#
#    DEVICE_TYPE_ID  INTERNET_TYPE_ID   REVENUE       ITC       VAS  \
# 0             5.0               2.0  0.128128  0.004327  0.084167
# 1             5.0               2.0  0.133601  0.015793  0.106932
# 2             3.0               3.0  0.118478  0.004834  0.085881
# 3             5.0               2.0  0.129951  0.002000  0.085055
# 4             3.0               3.0  0.108780  0.000103  0.084285
#
#    RENT_CHANNEL      ...           COST  COM_CAT_17  COM_CAT_18  COM_CAT_19  \
# 0      0.055287      ...       0.004673    0.000000         0.0    0.038407
# 1      0.055055      ...       0.007315    0.068165         0.0    0.026212
# 2      0.055038      ...       0.004817    0.000000         0.0    0.026212
# 3      0.063784      ...       0.005164    0.000000         0.0    0.026212
# 4      0.054984      ...       0.004226    0.000000         0.0    0.026212
#
#    COM_CAT_20  COM_CAT_21  COM_CAT_22  COM_CAT_23  COM_CAT_27  COM_CAT_28  \
# 0    0.705165    0.032714    0.704449    0.128508    0.003220    0.004140
# 1    0.705048    0.023984    0.702567    0.132894    0.008828    0.015793
# 2    0.701650    0.019298    0.701650    0.116275    0.014066    0.003972
# 3    0.705427    0.019298    0.705427    0.130530    0.003737    0.002000
# 4    0.698688    0.019298    0.698688    0.109785    0.001804    0.000103
#
#    COM_CAT_29  COM_CAT_30  COM_CAT_31  COM_CAT_32  COM_CAT_33  COM_CAT_34  \
# 0    0.000038    0.002244    0.029528    0.027579    0.103896         9.0
# 1    0.000972    0.000070    0.011613    0.027579    0.103896         9.0
# 2    0.000000    0.000000    0.039371    0.027579    0.103896         3.0
# 3    0.071332    0.001833    0.051395    0.027579    0.103896         2.0
# 4    0.000000    0.000000    0.012235    0.027579    0.103900         3.0
#
#    SUM_MINUTES  SUM_DATA_MB  SUM_DATA_MIN
# 0     0.144137     0.012112      1.093219
# 1     0.112944     0.009155      1.395130
# 2     0.246722     0.000000      0.000000
# 3     0.402554     0.416140      2.278583
# 4     0.073116     0.000000      0.000000
#
# [5 rows x 39 columns]

# %% [markdown]
# #### Baseline.

# %% [markdown]
# Train/test split.

# %%
split_index = 9443-5221

# %%
y = df[target]

# %%
X_train,X_test = df[:split_index].drop([target,'SK_ID'], axis = 1),df[split_index:].drop([target,'SK_ID'], axis = 1)

# %%
y_train = y[:split_index]

# %% [markdown]
# Данных мало, чтобы хоть как-то валидироваться, сделаем из тестовой выборки небольшую подвыборку для проверки результатов работы модели.

# %%
X_sub_train, X_sub_test, y_sub_train, y_sub_test = train_test_split(X_train, y_train, test_size=0.15, 
                                                    random_state=seed, shuffle=True, stratify = y_train)

# %% [markdown]
# Pipeline.

# %%
df_num_features = list(df).copy()
df_num_features.remove(target)
df_num_features.remove('SK_ID')
#df_num_features

# %%
num_features_pipeline = Pipeline([
    ('impute', SimpleImputer(missing_values=np.nan, strategy='mean',copy = False)),
    ('scale', MinMaxScaler()),
    ('transform', QuantileTransformer(output_distribution='normal'))
])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_features_pipeline, df_num_features),
        #('cat_ext', cat_ext_features_pipeline, cat_ext),
        #('cat_bin', cat_bin_features_pipeline, cat_bin)
    ]
)

# %%
clf_log = LogisticRegression(multi_class = 'ovr',
                             solver='liblinear',
                             random_state = seed,
                             n_jobs = -1,
                             max_iter = 10e2,
                             class_weight='balanced',
                             penalty = 'l2'
                            )

# %%
baseline_logit = Pipeline(
    steps=[
        ('preprocessing', preprocessor),
        ('classify', clf_log)
    ]
)

# %%
def plot_curve(fpr, tpr):
    plt.figure(figsize=(10, 10))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.5f)' % auc(fpr, tpr))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.01])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

# %%
def classify(estimator, X_train, X_test, y_train, y_test, return_prob):
    if (return_prob == True):
        y_pred_train = estimator.predict_proba(X_train)
        y_pred_test = estimator.predict_proba(X_test)
        
        print ("on train")
        print(classification_report(y_train, estimator.predict(X_train)))
        print ("AUC train")
        fpr, tpr, _ = roc_curve(y_train, y_pred_train[:, 1])
        print (auc(fpr, tpr))
        plot_curve(fpr, tpr)
        return y_pred_test[:, 1]
    elif(return_prob == False):
        y_pred_train = estimator.predict_proba(X_train)
        y_pred_test = estimator.predict_proba(X_test)
        
        print ("on train")
        print(classification_report(y_train, estimator.predict(X_train)))
        print ("AUC train")
        fpr, tpr, _ = roc_curve(y_train, y_pred_train[:, 1])
        print (auc(fpr, tpr))
        
        print ("on test")
        print(classification_report(y_test, estimator.predict(X_test)))
        print ("AUC test")
        fpr, tpr, _ = roc_curve(y_test, y_pred_test[:, 1])
        print (auc(fpr, tpr))

# %%
logit_regr = baseline_logit.fit(X_train, y_train)
# Out:
# E:\Python\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1296: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 4.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))

# %%
classify(logit_regr)
# Out:
# on train
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.55      0.68      3566
#          1.0       0.20      0.60      0.30       656
#
#    micro avg       0.56      0.56      0.56      4222
#    macro avg       0.54      0.58      0.49      4222
# weighted avg       0.78      0.56      0.62      4222
#
# AUC
# 0.595957074265078
# array([0.59833697, 0.56207288, 0.4104858 , ..., 0.53988544, 0.48118303,
#        0.41271777])

# %% [markdown]
# #### Hyperparameters tune.

# %%
# %%time

my_scorer = make_scorer(f1_score, average='weighted')
skv = KFold(n_splits = 10,random_state=seed, shuffle=False)

tuned_parameters = [
    {
    'classify__penalty': ['l2'],
    'classify__C': [0.01, 0.05, 0.1, 0.5, 1, 5, 10, 20, 40, 50]
                    
                    },
    {
    'classify__penalty': ['l1'],
    'classify__C': [0.01, 0.05, 0.1, 0.5, 1, 5, 10, 20, 40, 50]
                    }
    ]


bclf = GridSearchCV(baseline_logit, tuned_parameters,
                   scoring=my_scorer, cv=skv, verbose=9, n_jobs=-1,refit='roc_auc')

bclf.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  1.7min finished
# D:\Programs\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# Wall time: 1min 44s

# %%
#for key in baseline_logit.get_params().keys():
#    print(key)

# %%
#bclf.cv_results_

# %%
def create_cv_plot(estimator):
    alphas = estimator.cv_results_['param_classify__C'].data
    scores = estimator.cv_results_['mean_train_score']
    combined = pd.DataFrame({'C':alphas, 'score':scores})
    plt.figure(figsize=(18, 10))

    plt.plot(combined.C[0:20], combined.score[0:20],'go-')
    plt.grid(True)
    plt.title('C and metrics plt')
    plt.xlabel('C values') 
    plt.ylabel('mean_train_score error')

# %%
create_cv_plot(bclf)
# Out:
# D:\Programs\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
bclf.best_params_
# Out:
# {'classify__C': 0.5, 'classify__penalty': 'l1'}

# %%
baseline_logit.set_params(** bclf.best_params_)
# Out:
# Pipeline(memory=None,
#      steps=[('preprocessing', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('num', Pipeline(memory=None,
#      steps=[('impute', SimpleImputer(copy=False, fill_value=None, missing_values=nan,
#        strategy='mean', verbos...alty='l1', random_state=33,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False))])

# %%
log_with_best_params = baseline_logit.fit(X_train, y_train)
# Out:
# D:\Programs\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))

# %%
classify(log_with_best_params)
# Out:
# on train
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.56      0.68      3566
#          1.0       0.19      0.57      0.28       656
#
#    micro avg       0.56      0.56      0.56      4222
#    macro avg       0.53      0.56      0.48      4222
# weighted avg       0.77      0.56      0.62      4222
#
# AUC
# 0.587849079381147
# array([0.57466383, 0.58669228, 0.44884818, ..., 0.53527745, 0.50237596,
#        0.43990726])

# %%
#df.drop('COM_CAT_28',axis = 1, inplace = True)

#df.drop('COM_CAT_23',axis = 1, inplace = True)

#df.drop('COM_CAT_22',axis = 1, inplace = True)

#df.drop('COM_CAT_27',axis = 1, inplace = True) признак нужный
#df.drop('COM_CAT_21',axis = 1, inplace = True) # may be profit!
#df.drop('COM_CAT_20',axis = 1, inplace = True)
#df.drop('REVENUE',axis = 1, inplace = True) # need feature

# %%
# stabilized features as max improve rate
# here is rate 126
# both v3
df.drop('Month_CONTACT_DATE',axis = 1, inplace = True)# дроп этой фичи улучшает скор
df.drop('COM_CAT_26',axis = 1, inplace = True)# дроп этой фичи улучшает скор

# both v4
df.drop('Month_Snap_Date',axis = 1, inplace = True) #немного возрос auc
df.drop('Year_Snap_Date',axis = 1, inplace = True) # немного улучшает скор 0.80 and 0.45 by without drop day contact date
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1408-2e7704ac7d0b> in <module>()
#       1 # both v3
# ----> 2 df.drop('Month_CONTACT_DATE',axis = 1, inplace = True)# дроп этой фичи улучшает скор
#       3 df.drop('COM_CAT_26',axis = 1, inplace = True)# дроп этой фичи улучшает скор
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# E:\Python\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['Month_CONTACT_DATE'] not found in axis"

# %% [markdown]
# #### SVC.

# %%
from sklearn.feature_selection import SelectFromModel

# %%
X_sub_train, X_sub_test, y_sub_train, y_sub_test

# %%
anova_filter = SelectPercentile(f_classif, percentile = 35)

svc = SVC(kernel = 'rbf',
          gamma = 'scale',
          #C = 5, #with c = 5 strong overfit
          random_state = seed,          
          decision_function_shape = 'ovr',                             
          class_weight = 'balanced',     
          probability = True)

baseline_SVC = Pipeline(
    steps=[
        ('preprocessing', preprocessor),
        #('anova' , anova_filter),
        ('classify', svc)
    ]
)

# %%
cvs_classify = baseline_SVC.fit(X_sub_train, y_sub_train)

# %%
ft = baseline_SVC.named_steps['anova']

# %%
X_train.columns[ft.get_support()]
# Out:
# Index(['ARPU_GROUP', 'REVENUE', 'ITC', 'RENT_CHANNEL', 'COST', 'COM_CAT_20',
#        'COM_CAT_22', 'COM_CAT_23', 'COM_CAT_28', 'COM_CAT_29', 'SUM_DATA_MB',
#        'SUM_DATA_MIN'],
#       dtype='object')

# %%
cross_val_score(cvs_classify, X_train, y_train, cv=10, scoring='roc_auc',n_jobs = -1).mean()
# Out:
# 0.5440850296798743

# %%
results = classify(cvs_classify, X_sub_train, X_sub_test, y_sub_train, y_sub_test, False)
# Out:
# on train
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.68      0.79      3031
#          1.0       0.31      0.79      0.45       557
#
#    micro avg       0.70      0.70      0.70      3588
#    macro avg       0.63      0.74      0.62      3588
# weighted avg       0.85      0.70      0.74      3588
#
# AUC train
# 0.8116239907550169
# on test
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.60      0.71       535
#          1.0       0.17      0.43      0.24        99
#
#    micro avg       0.58      0.58      0.58       634
#    macro avg       0.51      0.52      0.47       634
# weighted avg       0.75      0.58      0.63       634
#
# AUC test
# 0.5352780137826867

# %%
results.shape
results = pd.DataFrame(results)

# %%
results.to_csv("out_svc_dropped_features_v5.csv", sep='\t', encoding='utf-8',index = False, header = False)

# %%
#print test

# %%
# %%time

my_scorer = make_scorer(f1_score, average='weighted')
skv = KFold(n_splits = 10,random_state=seed, shuffle=False)

'''    {
    'classify__kernel': ['poly'],
    'classify__degree': [1, 2, 3],
    'classify__coef0': [0, 0.5, 1],
    'classify__C': [0.01, 0.05, 0.1, 0.5, 1, 5, 10, 20]
                    },'''

tuned_parameters = [
    {
    'classify__kernel': ['poly'],
    'classify__degree': [1, 2, 3],
    'classify__coef0': [0, 0.5, 1],
    'classify__C': [0.01, 0.05, 0.1, 0.5, 1, 5, 10, 20]
                    },

    {
    'classify__kernel': ['rbf'],
    'classify__C': [0.01, 0.05, 0.1, 0.5, 1, 5, 10, 20, 40],
    'classify__gamma': [0.001,0.01, 0.05, 0.1, 0.5, 1]
                    },
    {
    'classify__kernel': [ 'sigmoid'],
    'classify__C': [0.01, 0.05, 0.1, 0.5, 1, 5, 10, 20, 40],
    'classify__coef0': [0.1, 0.5, 1, 5]
                    }
]


bsvc = GridSearchCV(baseline_SVC, tuned_parameters,
                   scoring=my_scorer, cv=skv, verbose=8, n_jobs=-1,refit='roc_auc')

#bsvc.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 162 candidates, totalling 1620 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   56.6s
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 745 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 866 tasks      | elapsed: 19.4min
# [Parallel(n_jobs=-1)]: Done 997 tasks      | elapsed: 22.0min
# [Parallel(n_jobs=-1)]: Done 1136 tasks      | elapsed: 24.7min
# [Parallel(n_jobs=-1)]: Done 1285 tasks      | elapsed: 27.6min
# [Parallel(n_jobs=-1)]: Done 1442 tasks      | elapsed: 30.8min
# [Parallel(n_jobs=-1)]: Done 1620 out of 1620 | elapsed: 33.7min finished
# Wall time: 33min 45s

# %%
means = bsvc.cv_results_['mean_test_score']
stds = bsvc.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, bsvc.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
# Out:
# 0.511 (+/-0.066) for {'classify__C': 0.01, 'classify__coef0': 0, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.546 (+/-0.058) for {'classify__C': 0.01, 'classify__coef0': 0, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.619 (+/-0.053) for {'classify__C': 0.01, 'classify__coef0': 0, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.511 (+/-0.066) for {'classify__C': 0.01, 'classify__coef0': 0.5, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.539 (+/-0.058) for {'classify__C': 0.01, 'classify__coef0': 0.5, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.628 (+/-0.061) for {'classify__C': 0.01, 'classify__coef0': 0.5, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.511 (+/-0.066) for {'classify__C': 0.01, 'classify__coef0': 1, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.534 (+/-0.058) for {'classify__C': 0.01, 'classify__coef0': 1, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.627 (+/-0.064) for {'classify__C': 0.01, 'classify__coef0': 1, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.503 (+/-0.030) for {'classify__C': 0.05, 'classify__coef0': 0, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.586 (+/-0.057) for {'classify__C': 0.05, 'classify__coef0': 0, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.633 (+/-0.064) for {'classify__C': 0.05, 'classify__coef0': 0, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.503 (+/-0.030) for {'classify__C': 0.05, 'classify__coef0': 0.5, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.589 (+/-0.061) for {'classify__C': 0.05, 'classify__coef0': 0.5, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.631 (+/-0.064) for {'classify__C': 0.05, 'classify__coef0': 0.5, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.503 (+/-0.030) for {'classify__C': 0.05, 'classify__coef0': 1, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.591 (+/-0.061) for {'classify__C': 0.05, 'classify__coef0': 1, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.631 (+/-0.066) for {'classify__C': 0.05, 'classify__coef0': 1, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.495 (+/-0.047) for {'classify__C': 0.1, 'classify__coef0': 0, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.623 (+/-0.065) for {'classify__C': 0.1, 'classify__coef0': 0, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.629 (+/-0.062) for {'classify__C': 0.1, 'classify__coef0': 0, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.495 (+/-0.047) for {'classify__C': 0.1, 'classify__coef0': 0.5, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.624 (+/-0.064) for {'classify__C': 0.1, 'classify__coef0': 0.5, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.628 (+/-0.065) for {'classify__C': 0.1, 'classify__coef0': 0.5, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.495 (+/-0.047) for {'classify__C': 0.1, 'classify__coef0': 1, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.622 (+/-0.064) for {'classify__C': 0.1, 'classify__coef0': 1, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.625 (+/-0.066) for {'classify__C': 0.1, 'classify__coef0': 1, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.514 (+/-0.069) for {'classify__C': 0.5, 'classify__coef0': 0, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.635 (+/-0.053) for {'classify__C': 0.5, 'classify__coef0': 0, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.635 (+/-0.044) for {'classify__C': 0.5, 'classify__coef0': 0, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.514 (+/-0.068) for {'classify__C': 0.5, 'classify__coef0': 0.5, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.637 (+/-0.051) for {'classify__C': 0.5, 'classify__coef0': 0.5, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.633 (+/-0.043) for {'classify__C': 0.5, 'classify__coef0': 0.5, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.514 (+/-0.069) for {'classify__C': 0.5, 'classify__coef0': 1, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.636 (+/-0.052) for {'classify__C': 0.5, 'classify__coef0': 1, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.633 (+/-0.040) for {'classify__C': 0.5, 'classify__coef0': 1, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.542 (+/-0.072) for {'classify__C': 1, 'classify__coef0': 0, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.631 (+/-0.054) for {'classify__C': 1, 'classify__coef0': 0, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.640 (+/-0.030) for {'classify__C': 1, 'classify__coef0': 0, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.542 (+/-0.072) for {'classify__C': 1, 'classify__coef0': 0.5, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.630 (+/-0.055) for {'classify__C': 1, 'classify__coef0': 0.5, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.638 (+/-0.032) for {'classify__C': 1, 'classify__coef0': 0.5, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.542 (+/-0.073) for {'classify__C': 1, 'classify__coef0': 1, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.629 (+/-0.055) for {'classify__C': 1, 'classify__coef0': 1, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.638 (+/-0.027) for {'classify__C': 1, 'classify__coef0': 1, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.569 (+/-0.072) for {'classify__C': 5, 'classify__coef0': 0, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.622 (+/-0.057) for {'classify__C': 5, 'classify__coef0': 0, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.647 (+/-0.042) for {'classify__C': 5, 'classify__coef0': 0, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.569 (+/-0.071) for {'classify__C': 5, 'classify__coef0': 0.5, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.624 (+/-0.052) for {'classify__C': 5, 'classify__coef0': 0.5, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.649 (+/-0.043) for {'classify__C': 5, 'classify__coef0': 0.5, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.570 (+/-0.072) for {'classify__C': 5, 'classify__coef0': 1, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.625 (+/-0.050) for {'classify__C': 5, 'classify__coef0': 1, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.651 (+/-0.041) for {'classify__C': 5, 'classify__coef0': 1, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.576 (+/-0.068) for {'classify__C': 10, 'classify__coef0': 0, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.626 (+/-0.046) for {'classify__C': 10, 'classify__coef0': 0, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.662 (+/-0.041) for {'classify__C': 10, 'classify__coef0': 0, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.576 (+/-0.068) for {'classify__C': 10, 'classify__coef0': 0.5, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.628 (+/-0.049) for {'classify__C': 10, 'classify__coef0': 0.5, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.661 (+/-0.048) for {'classify__C': 10, 'classify__coef0': 0.5, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.577 (+/-0.068) for {'classify__C': 10, 'classify__coef0': 1, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.625 (+/-0.045) for {'classify__C': 10, 'classify__coef0': 1, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.660 (+/-0.052) for {'classify__C': 10, 'classify__coef0': 1, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.580 (+/-0.065) for {'classify__C': 20, 'classify__coef0': 0, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.629 (+/-0.047) for {'classify__C': 20, 'classify__coef0': 0, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.669 (+/-0.048) for {'classify__C': 20, 'classify__coef0': 0, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.580 (+/-0.064) for {'classify__C': 20, 'classify__coef0': 0.5, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.631 (+/-0.044) for {'classify__C': 20, 'classify__coef0': 0.5, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.671 (+/-0.051) for {'classify__C': 20, 'classify__coef0': 0.5, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.580 (+/-0.063) for {'classify__C': 20, 'classify__coef0': 1, 'classify__degree': 1, 'classify__kernel': 'poly'}
# 0.632 (+/-0.044) for {'classify__C': 20, 'classify__coef0': 1, 'classify__degree': 2, 'classify__kernel': 'poly'}
# 0.672 (+/-0.057) for {'classify__C': 20, 'classify__coef0': 1, 'classify__degree': 3, 'classify__kernel': 'poly'}
# 0.257 (+/-0.661) for {'classify__C': 0.01, 'classify__gamma': 0.001, 'classify__kernel': 'rbf'}
# 0.265 (+/-0.652) for {'classify__C': 0.01, 'classify__gamma': 0.01, 'classify__kernel': 'rbf'}
# 0.257 (+/-0.661) for {'classify__C': 0.01, 'classify__gamma': 0.05, 'classify__kernel': 'rbf'}
# 0.257 (+/-0.661) for {'classify__C': 0.01, 'classify__gamma': 0.1, 'classify__kernel': 'rbf'}
# 0.257 (+/-0.661) for {'classify__C': 0.01, 'classify__gamma': 0.5, 'classify__kernel': 'rbf'}
# 0.257 (+/-0.661) for {'classify__C': 0.01, 'classify__gamma': 1, 'classify__kernel': 'rbf'}
# 0.531 (+/-0.071) for {'classify__C': 0.05, 'classify__gamma': 0.001, 'classify__kernel': 'rbf'}
# 0.644 (+/-0.036) for {'classify__C': 0.05, 'classify__gamma': 0.01, 'classify__kernel': 'rbf'}
# 0.623 (+/-0.203) for {'classify__C': 0.05, 'classify__gamma': 0.05, 'classify__kernel': 'rbf'}
# 0.199 (+/-0.389) for {'classify__C': 0.05, 'classify__gamma': 0.1, 'classify__kernel': 'rbf'}
# 0.121 (+/-0.463) for {'classify__C': 0.05, 'classify__gamma': 0.5, 'classify__kernel': 'rbf'}
# 0.121 (+/-0.463) for {'classify__C': 0.05, 'classify__gamma': 1, 'classify__kernel': 'rbf'}
# 0.540 (+/-0.053) for {'classify__C': 0.1, 'classify__gamma': 0.001, 'classify__kernel': 'rbf'}
# 0.649 (+/-0.054) for {'classify__C': 0.1, 'classify__gamma': 0.01, 'classify__kernel': 'rbf'}
# 0.681 (+/-0.097) for {'classify__C': 0.1, 'classify__gamma': 0.05, 'classify__kernel': 'rbf'}
# 0.504 (+/-0.272) for {'classify__C': 0.1, 'classify__gamma': 0.1, 'classify__kernel': 'rbf'}
# 0.121 (+/-0.463) for {'classify__C': 0.1, 'classify__gamma': 0.5, 'classify__kernel': 'rbf'}
# 0.121 (+/-0.463) for {'classify__C': 0.1, 'classify__gamma': 1, 'classify__kernel': 'rbf'}
# 0.535 (+/-0.062) for {'classify__C': 0.5, 'classify__gamma': 0.001, 'classify__kernel': 'rbf'}
# 0.646 (+/-0.054) for {'classify__C': 0.5, 'classify__gamma': 0.01, 'classify__kernel': 'rbf'}
# 0.710 (+/-0.057) for {'classify__C': 0.5, 'classify__gamma': 0.05, 'classify__kernel': 'rbf'}
# 0.747 (+/-0.052) for {'classify__C': 0.5, 'classify__gamma': 0.1, 'classify__kernel': 'rbf'}
# 0.773 (+/-0.060) for {'classify__C': 0.5, 'classify__gamma': 0.5, 'classify__kernel': 'rbf'}
# 0.774 (+/-0.059) for {'classify__C': 0.5, 'classify__gamma': 1, 'classify__kernel': 'rbf'}
# 0.556 (+/-0.068) for {'classify__C': 1, 'classify__gamma': 0.001, 'classify__kernel': 'rbf'}
# 0.648 (+/-0.048) for {'classify__C': 1, 'classify__gamma': 0.01, 'classify__kernel': 'rbf'}
# 0.721 (+/-0.047) for {'classify__C': 1, 'classify__gamma': 0.05, 'classify__kernel': 'rbf'}
# 0.753 (+/-0.056) for {'classify__C': 1, 'classify__gamma': 0.1, 'classify__kernel': 'rbf'}
# 0.773 (+/-0.060) for {'classify__C': 1, 'classify__gamma': 0.5, 'classify__kernel': 'rbf'}
# 0.774 (+/-0.059) for {'classify__C': 1, 'classify__gamma': 1, 'classify__kernel': 'rbf'}
# 0.622 (+/-0.071) for {'classify__C': 5, 'classify__gamma': 0.001, 'classify__kernel': 'rbf'}
# 0.659 (+/-0.041) for {'classify__C': 5, 'classify__gamma': 0.01, 'classify__kernel': 'rbf'}
# 0.745 (+/-0.059) for {'classify__C': 5, 'classify__gamma': 0.05, 'classify__kernel': 'rbf'}
# 0.765 (+/-0.057) for {'classify__C': 5, 'classify__gamma': 0.1, 'classify__kernel': 'rbf'}
# 0.773 (+/-0.060) for {'classify__C': 5, 'classify__gamma': 0.5, 'classify__kernel': 'rbf'}
# 0.774 (+/-0.059) for {'classify__C': 5, 'classify__gamma': 1, 'classify__kernel': 'rbf'}
# 0.632 (+/-0.068) for {'classify__C': 10, 'classify__gamma': 0.001, 'classify__kernel': 'rbf'}
# 0.666 (+/-0.050) for {'classify__C': 10, 'classify__gamma': 0.01, 'classify__kernel': 'rbf'}
# 0.749 (+/-0.058) for {'classify__C': 10, 'classify__gamma': 0.05, 'classify__kernel': 'rbf'}
# 0.769 (+/-0.052) for {'classify__C': 10, 'classify__gamma': 0.1, 'classify__kernel': 'rbf'}
# 0.773 (+/-0.060) for {'classify__C': 10, 'classify__gamma': 0.5, 'classify__kernel': 'rbf'}
# 0.774 (+/-0.059) for {'classify__C': 10, 'classify__gamma': 1, 'classify__kernel': 'rbf'}
# 0.629 (+/-0.067) for {'classify__C': 20, 'classify__gamma': 0.001, 'classify__kernel': 'rbf'}
# 0.684 (+/-0.060) for {'classify__C': 20, 'classify__gamma': 0.01, 'classify__kernel': 'rbf'}
# 0.754 (+/-0.056) for {'classify__C': 20, 'classify__gamma': 0.05, 'classify__kernel': 'rbf'}
# 0.769 (+/-0.051) for {'classify__C': 20, 'classify__gamma': 0.1, 'classify__kernel': 'rbf'}
# 0.773 (+/-0.060) for {'classify__C': 20, 'classify__gamma': 0.5, 'classify__kernel': 'rbf'}
# 0.774 (+/-0.059) for {'classify__C': 20, 'classify__gamma': 1, 'classify__kernel': 'rbf'}
# 0.624 (+/-0.070) for {'classify__C': 40, 'classify__gamma': 0.001, 'classify__kernel': 'rbf'}
# 0.697 (+/-0.056) for {'classify__C': 40, 'classify__gamma': 0.01, 'classify__kernel': 'rbf'}
# 0.757 (+/-0.057) for {'classify__C': 40, 'classify__gamma': 0.05, 'classify__kernel': 'rbf'}
# 0.769 (+/-0.052) for {'classify__C': 40, 'classify__gamma': 0.1, 'classify__kernel': 'rbf'}
# 0.773 (+/-0.060) for {'classify__C': 40, 'classify__gamma': 0.5, 'classify__kernel': 'rbf'}
# 0.774 (+/-0.059) for {'classify__C': 40, 'classify__gamma': 1, 'classify__kernel': 'rbf'}
# 0.088 (+/-0.073) for {'classify__C': 0.01, 'classify__coef0': 0.1, 'classify__kernel': 'sigmoid'}
# 0.188 (+/-0.519) for {'classify__C': 0.01, 'classify__coef0': 0.5, 'classify__kernel': 'sigmoid'}
# 0.257 (+/-0.661) for {'classify__C': 0.01, 'classify__coef0': 1, 'classify__kernel': 'sigmoid'}
# 0.257 (+/-0.661) for {'classify__C': 0.01, 'classify__coef0': 5, 'classify__kernel': 'sigmoid'}
# 0.213 (+/-0.151) for {'classify__C': 0.05, 'classify__coef0': 0.1, 'classify__kernel': 'sigmoid'}
# 0.132 (+/-0.043) for {'classify__C': 0.05, 'classify__coef0': 0.5, 'classify__kernel': 'sigmoid'}
# 0.106 (+/-0.042) for {'classify__C': 0.05, 'classify__coef0': 1, 'classify__kernel': 'sigmoid'}
# 0.121 (+/-0.463) for {'classify__C': 0.05, 'classify__coef0': 5, 'classify__kernel': 'sigmoid'}
# 0.546 (+/-0.066) for {'classify__C': 0.1, 'classify__coef0': 0.1, 'classify__kernel': 'sigmoid'}
# 0.527 (+/-0.086) for {'classify__C': 0.1, 'classify__coef0': 0.5, 'classify__kernel': 'sigmoid'}
# 0.135 (+/-0.039) for {'classify__C': 0.1, 'classify__coef0': 1, 'classify__kernel': 'sigmoid'}
# 0.121 (+/-0.463) for {'classify__C': 0.1, 'classify__coef0': 5, 'classify__kernel': 'sigmoid'}
# 0.584 (+/-0.055) for {'classify__C': 0.5, 'classify__coef0': 0.1, 'classify__kernel': 'sigmoid'}
# 0.584 (+/-0.048) for {'classify__C': 0.5, 'classify__coef0': 0.5, 'classify__kernel': 'sigmoid'}
# 0.555 (+/-0.056) for {'classify__C': 0.5, 'classify__coef0': 1, 'classify__kernel': 'sigmoid'}
# 0.473 (+/-0.714) for {'classify__C': 0.5, 'classify__coef0': 5, 'classify__kernel': 'sigmoid'}
# 0.588 (+/-0.051) for {'classify__C': 1, 'classify__coef0': 0.1, 'classify__kernel': 'sigmoid'}
# 0.584 (+/-0.045) for {'classify__C': 1, 'classify__coef0': 0.5, 'classify__kernel': 'sigmoid'}
# 0.576 (+/-0.067) for {'classify__C': 1, 'classify__coef0': 1, 'classify__kernel': 'sigmoid'}
# 0.473 (+/-0.714) for {'classify__C': 1, 'classify__coef0': 5, 'classify__kernel': 'sigmoid'}
# 0.571 (+/-0.060) for {'classify__C': 5, 'classify__coef0': 0.1, 'classify__kernel': 'sigmoid'}
# 0.582 (+/-0.050) for {'classify__C': 5, 'classify__coef0': 0.5, 'classify__kernel': 'sigmoid'}
# 0.571 (+/-0.059) for {'classify__C': 5, 'classify__coef0': 1, 'classify__kernel': 'sigmoid'}
# 0.551 (+/-0.672) for {'classify__C': 5, 'classify__coef0': 5, 'classify__kernel': 'sigmoid'}
# 0.567 (+/-0.036) for {'classify__C': 10, 'classify__coef0': 0.1, 'classify__kernel': 'sigmoid'}
# 0.579 (+/-0.054) for {'classify__C': 10, 'classify__coef0': 0.5, 'classify__kernel': 'sigmoid'}
# 0.560 (+/-0.056) for {'classify__C': 10, 'classify__coef0': 1, 'classify__kernel': 'sigmoid'}
# 0.551 (+/-0.672) for {'classify__C': 10, 'classify__coef0': 5, 'classify__kernel': 'sigmoid'}
# 0.567 (+/-0.039) for {'classify__C': 20, 'classify__coef0': 0.1, 'classify__kernel': 'sigmoid'}
# 0.573 (+/-0.040) for {'classify__C': 20, 'classify__coef0': 0.5, 'classify__kernel': 'sigmoid'}
# 0.555 (+/-0.053) for {'classify__C': 20, 'classify__coef0': 1, 'classify__kernel': 'sigmoid'}
# 0.550 (+/-0.671) for {'classify__C': 20, 'classify__coef0': 5, 'classify__kernel': 'sigmoid'}
# 0.563 (+/-0.046) for {'classify__C': 40, 'classify__coef0': 0.1, 'classify__kernel': 'sigmoid'}
# 0.568 (+/-0.047) for {'classify__C': 40, 'classify__coef0': 0.5, 'classify__kernel': 'sigmoid'}
# 0.555 (+/-0.047) for {'classify__C': 40, 'classify__coef0': 1, 'classify__kernel': 'sigmoid'}
# 0.122 (+/-0.420) for {'classify__C': 40, 'classify__coef0': 5, 'classify__kernel': 'sigmoid'}

# %%
bsvc.best_params_
# Out:
# {'classify__C': 0.5, 'classify__gamma': 1, 'classify__kernel': 'rbf'}

# %%
baseline_SVC.set_params(** bsvc.best_params_)
# Out:
# Pipeline(memory=None,
#      steps=[('preprocessing', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('num', Pipeline(memory=None,
#      steps=[('impute', SimpleImputer(copy=False, fill_value=None, missing_values=nan,
#        strategy='mean', verbos...bf',
#   max_iter=-1, probability=True, random_state=33, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
#baseline_SVC.named_steps

# %%
results = classify(baseline_SVC)
# Out:
# on train
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      3566
#          1.0       1.00      1.00      1.00       656
#
#    micro avg       1.00      1.00      1.00      4222
#    macro avg       1.00      1.00      1.00      4222
# weighted avg       1.00      1.00      1.00      4222
#
# AUC
# 0.0

# %%
results.shape
results = pd.DataFrame(results)

# %%
results.to_csv("out_svc_best_params.csv", sep='\t', encoding='utf-8',index = False, header = False)

# %% [markdown]
# #### Feature Importance. Oversample. XGBOOST.

# %%
clf_log = LogisticRegression(multi_class = 'ovr',
                             solver='saga',
                             random_state = seed,
                             n_jobs = -1,
                             max_iter = 10e2,
                             class_weight='balanced',
                             penalty = 'l1',
                             C = 40
                            )

# %%
baseline_logit = Pipeline(
    steps=[
        ('preprocessing', preprocessor),
        ('classify', clf_log)
    ]
)

# %%
most_ft = baseline_logit.fit(X_train,y_train)

# %%
results = classify(most_ft)
# Out:
# on train
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.55      0.68      3566
#          1.0       0.19      0.59      0.29       656
#
#    micro avg       0.56      0.56      0.56      4222
#    macro avg       0.54      0.57      0.48      4222
# weighted avg       0.77      0.56      0.62      4222
#
# AUC
# 0.593646122594148

# %%
results.shape
results = pd.DataFrame(results)

# %%
results.to_csv("out.csv", sep='\t', encoding='utf-8',index = False, header = False)

# %%
coefs = most_ft.steps[1][1].coef_

# %%
coefs = pd.DataFrame(np.abs(coefs), columns = (df_num_features))

# %%
coefs[coefs > 0.1].T
# Out:
#                          0
# Year_Snap_Date         NaN
# Day_CONTACT_DATE       NaN
# COM_CAT_1              NaN
# COM_CAT_2              NaN
# COM_CAT_3              NaN
# BASE_TYPE              NaN
# ACT                    NaN
# ARPU_GROUP             NaN
# COM_CAT_7              NaN
# COM_CAT_8              NaN
# DEVICE_TYPE_ID         NaN
# INTERNET_TYPE_ID       NaN
# VAS               0.207431
# RENT_CHANNEL           NaN
# ROAM                   NaN
# COST              0.193749
# COM_CAT_17             NaN
# COM_CAT_18             NaN
# COM_CAT_19        0.214457
# COM_CAT_21        0.357297
# COM_CAT_22             NaN
# COM_CAT_23        0.213427
# COM_CAT_27        0.100604
# COM_CAT_28             NaN
# COM_CAT_29             NaN
# COM_CAT_30             NaN
# COM_CAT_31             NaN
# COM_CAT_32             NaN
# COM_CAT_33             NaN
# COM_CAT_34             NaN
# SUM_MINUTES            NaN
# SUM_DATA_MB       0.103953
# SUM_DATA_MIN      0.124359

# %% [markdown]
# #### XGBoost.

# %%
# fit model no training data
params={
    'n_estimators':400,
    'objective': 'binary:logistic',
    'learning_rate': 0.05,
    'gamma':0.1,
    'subsample':0.8,
    'colsample_bytree':0.3,
    'min_child_weight':4,
    'max_depth':5,
    'seed':seed,
    'eval_metric':'auc',
    
    }

xbg_clf = XGBClassifier(**params)

# %%
baseline_logit = Pipeline(
    steps=[
        ('preprocessing', preprocessor),
        ('classify', xbg_clf)
    ]
)

# %%
xgb = baseline_logit.fit(X_train,y_train)

# %%
results = classify(xgb)
# Out:
# on train
#               precision    recall  f1-score   support
#
#          0.0       0.89      1.00      0.94      3566
#          1.0       1.00      0.31      0.48       656
#
#    micro avg       0.89      0.89      0.89      4222
#    macro avg       0.94      0.66      0.71      4222
# weighted avg       0.91      0.89      0.87      4222
#
# AUC
# 0.990805353405469

# %%
results.shape
results = pd.DataFrame(results)

# %%
results.to_csv("xgb_v1.csv", sep='\t', encoding='utf-8',index = False, header = False)
